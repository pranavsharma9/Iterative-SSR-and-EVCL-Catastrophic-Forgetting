# %%
import json
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel
from datasets import Dataset
from torch.utils.data import DataLoader
import torch
import pyro
import pyro.distributions as dist
from tqdm import tqdm

# Load the JSON file
file_path = "/home/pranav24/cs-546-project/SSR/Latest_Weights/QA_Weights/task024_cosmosqa_answer_generation.json"
with open(file_path, "r") as f:
    data = json.load(f)

# Extract input-output pairs from JSON
instances = data["Instances"][2500:5000]
inputs = [instance["input"] for instance in instances]
outputs = [instance["output"][0] for instance in instances]

# Split the data into train and test sets
train_inputs, test_inputs, train_outputs, test_outputs = train_test_split(
    inputs, outputs, test_size=0.2, random_state=42
)

# Convert data to Hugging Face Dataset format
train_ds = Dataset.from_dict({"input": train_inputs, "output": train_outputs})
test_ds = Dataset.from_dict({"input": test_inputs, "output": test_outputs})

# Tokenizer setup
base_model_path = "meta-llama/Meta-Llama-3-8B"  # Replace with actual model path
tokenizer = AutoTokenizer.from_pretrained(base_model_path)

# Check if tokenizer has a padding token, if not, set the eos_token as padding token
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Tokenization function
def tokenize_function(examples):
    model_inputs = tokenizer(
        examples["input"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )
    labels = tokenizer(
        examples["output"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )["input_ids"]
    model_inputs["labels"] = labels
    return model_inputs

# Tokenize datasets
tokenized_train_ds = train_ds.map(tokenize_function, batched=True, remove_columns=["input", "output"])
tokenized_test_ds = test_ds.map(tokenize_function, batched=True, remove_columns=["input", "output"])

# Convert datasets to PyTorch format
tokenized_train_ds.set_format("torch")
tokenized_test_ds.set_format("torch")

# Create DataLoaders
batch_size = 16  # Adjust as needed
train_loader = DataLoader(tokenized_train_ds, batch_size=batch_size, shuffle=True)
eval_loader = DataLoader(tokenized_test_ds, batch_size=batch_size)

# Define the model and load weights
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_enable_fp32_cpu_offload=True,
)
fine_tuned_weights_path = "/home/pranav24/cs-546-project/finetuned-weights-LoRA-EVCL-Final-Task2_EVCL_best"

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    quantization_config=bnb_config,
    device_map="auto"
)
model = PeftModel.from_pretrained(base_model, fine_tuned_weights_path)
pyro.get_param_store().load('pyro_param_store_task2_vcl_best.pt')

# Ensure compatibility with the unchanged part of the code
DEVICE = model.device

# Generate predictions
predictions = []
references = []
sampled_weights_log = []  # Store sampled weights

print("Generating predictions:")

for i in tqdm(range(0, len(test_inputs), batch_size)):  # Loop in batches
    batch_inputs = test_inputs[i:i + batch_size]
    batch_references = test_outputs[i:i + batch_size]

    # Tokenize the inputs in a batch
    inputs_tokenized = tokenizer(batch_inputs, padding=True, truncation=True, return_tensors="pt").to(DEVICE)

    with torch.no_grad():
        with torch.cuda.amp.autocast():
            # Apply Pyro parameters to LoRA layers
            for name, module in model.named_modules():
                if hasattr(module, "lora_A"):
                    for key in module.lora_A:
                        loc = pyro.param(f"{name}.lora_A.{key}_loc")
                        scale = pyro.param(f"{name}.lora_A.{key}_scale")
                        sampled_weight = pyro.sample(
                            f"{name}.lora_A.{key}",
                            dist.Normal(loc, scale).to_event(loc.dim())
                        )
                        sampled_weights_log.append(
                            (name, key, sampled_weight.clone().cpu().numpy())
                        )
                        module.lora_A[key].weight.data.copy_(sampled_weight)

                if hasattr(module, "lora_B"):
                    for key in module.lora_B:
                        loc = pyro.param(f"{name}.lora_B.{key}_loc")
                        scale = pyro.param(f"{name}.lora_B.{key}_scale")
                        sampled_weight = pyro.sample(
                            f"{name}.lora_B.{key}",
                            dist.Normal(loc, scale).to_event(loc.dim())
                        )
                        sampled_weights_log.append(
                            (name, key, sampled_weight.clone().cpu().numpy())
                        )
                        module.lora_B[key].weight.data.copy_(sampled_weight)

            # Generate predictions using the tokenized inputs
            generated_ids = model.generate(
                input_ids=inputs_tokenized["input_ids"],
                attention_mask=inputs_tokenized["attention_mask"],
                max_length=1000,  # Adjust as needed
                num_return_sequences=1,
                do_sample=True  # Optional: Sampling for diverse generations
            )

        # Decode generated IDs
        batch_predictions = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        predictions.extend(batch_predictions)
        references.extend(batch_references)
# Out:
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# /home/pranav24/cs-546-project/venv/lib/python3.11/site-packages/pyro/params/param_store.py:334: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(input_file, map_location)
# Generating predictions:
#   0%|          | 0/32 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# /tmp/ipykernel_9238/2559409691.py:102: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 1/32 [02:18<1:11:26, 138.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 2/32 [04:37<1:09:28, 138.96s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   9%|▉         | 3/32 [06:56<1:07:11, 139.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  12%|█▎        | 4/32 [09:11<1:04:08, 137.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  16%|█▌        | 5/32 [11:35<1:02:47, 139.53s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  19%|█▉        | 6/32 [13:44<58:57, 136.07s/it]  Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  22%|██▏       | 7/32 [15:58<56:29, 135.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  25%|██▌       | 8/32 [18:16<54:25, 136.06s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  28%|██▊       | 9/32 [20:55<54:55, 143.27s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  31%|███▏      | 10/32 [23:48<55:53, 152.41s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  34%|███▍      | 11/32 [26:28<54:14, 154.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  38%|███▊      | 12/32 [29:03<51:37, 154.86s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  41%|████      | 13/32 [31:43<49:33, 156.51s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  44%|████▍     | 14/32 [34:28<47:42, 159.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  47%|████▋     | 15/32 [37:09<45:12, 159.58s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  50%|█████     | 16/32 [40:02<43:36, 163.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  53%|█████▎    | 17/32 [42:42<40:39, 162.66s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  56%|█████▋    | 18/32 [45:32<38:28, 164.88s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  59%|█████▉    | 19/32 [48:20<35:53, 165.65s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  62%|██████▎   | 20/32 [51:12<33:30, 167.52s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  66%|██████▌   | 21/32 [53:59<30:40, 167.31s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  69%|██████▉   | 22/32 [56:50<28:06, 168.69s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  72%|███████▏  | 23/32 [59:39<25:18, 168.73s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  75%|███████▌  | 24/32 [1:01:53<21:05, 158.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  78%|███████▊  | 25/32 [1:04:09<17:40, 151.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  81%|████████▏ | 26/32 [1:06:22<14:37, 146.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  84%|████████▍ | 27/32 [1:08:37<11:52, 142.59s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  88%|████████▊ | 28/32 [1:11:09<09:42, 145.50s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  91%|█████████ | 29/32 [1:14:01<07:40, 153.43s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  94%|█████████▍| 30/32 [1:16:34<05:06, 153.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 31/32 [1:18:54<02:29, 149.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|██████████| 32/32 [1:21:04<00:00, 152.02s/it]

# %%
# test_inputs=["Context: Then I drove all around to the used DVD stores to get season 2. ( which I found for 20 bucks! ) I have been watching a disk a night, and not going to bed until 3 am because I knew that the new season was starting soon and I didn't want to be behind. I just finished season 2 and was on the edge of my seat the whole last episode. Yesterday I taped what was on tv. Question: What does the narrator think about the price of the DVD set purchased?"]
import json
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel
from datasets import Dataset
from torch.utils.data import DataLoader
import torch
import pyro
import pyro.distributions as dist
from tqdm import tqdm

test_inputs=["Context: Good Old War and person L : I saw both of these bands Wednesday night , and they both blew me away . seriously . Good Old War is acoustic and makes me smile . I really can not help but be happy when I listen to them ; I think it 's the fact that they seemed so happy themselves when they played . Question: In the future , will this person go to see other bands play ?"]
batch_size=1
final_answer=[]

base_model_path = "meta-llama/Meta-Llama-3-8B"
# fine_tuned_weights_path = "/home/pranav24/cs-546-project/finetuned-weights-LoRA-EVCL-Final-Task1_VCL_best"

fine_tuned_weights_path="/home/pranav24/cs-546-project/finetuned-weights-LoRA-EVCL-Test-Task1_VCL"
pyro.get_param_store().load('pyro_param_store_task1_vcl.pt')

tokenizer = AutoTokenizer.from_pretrained(base_model_path)

# Check if tokenizer has a padding token, if not, set the eos_token as padding token
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Tokenization function
def tokenize_function(examples):
    model_inputs = tokenizer(
        examples["input"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )
    labels = tokenizer(
        examples["output"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )["input_ids"]
    model_inputs["labels"] = labels
    return model_inputs
# pyro.clear_param_store()

bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_enable_fp32_cpu_offload=True,
)

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    quantization_config=bnb_config,
    device_map="auto"
)
model = PeftModel.from_pretrained(base_model, fine_tuned_weights_path)
# pyro.get_param_store().load('pyro_param_store_task1_vcl_best.pt')
# pyro.get_param_store().load('pyro_param_store_task1_vcl_best.pt')

# Ensure compatibility with the unchanged part of the code
DEVICE = model.device

sampled_weights_log=[]
for i in tqdm(range(0, len(test_inputs), batch_size)):  # Loop in batches
    batch_inputs = test_inputs[i:i + batch_size]
    # batch_references = test_outputs[i:i + batch_size]

    # Tokenize the inputs in a batch
    inputs_tokenized = tokenizer(batch_inputs, padding=True, truncation=True, return_tensors="pt").to(DEVICE)

    with torch.no_grad():
        with torch.cuda.amp.autocast():
            # Apply Pyro parameters to LoRA layers
            for name, module in model.named_modules():
                if hasattr(module, "lora_A"):
                    for key in module.lora_A:
                        loc = pyro.param(f"{name}.lora_A.{key}_loc")
                        scale = pyro.param(f"{name}.lora_A.{key}_scale")
                        sampled_weight = pyro.sample(
                            f"{name}.lora_A.{key}",
                            dist.Normal(loc, scale).to_event(loc.dim())
                        )
                        sampled_weights_log.append(
                            (name, key, sampled_weight.clone().cpu().numpy())
                        )
                        module.lora_A[key].weight.data.copy_(sampled_weight)

                if hasattr(module, "lora_B"):
                    for key in module.lora_B:
                        loc = pyro.param(f"{name}.lora_B.{key}_loc")
                        scale = pyro.param(f"{name}.lora_B.{key}_scale")
                        sampled_weight = pyro.sample(
                            f"{name}.lora_B.{key}",
                            dist.Normal(loc, scale).to_event(loc.dim())
                        )
                        sampled_weights_log.append(
                            (name, key, sampled_weight.clone().cpu().numpy())
                        )
                        module.lora_B[key].weight.data.copy_(sampled_weight)

            # Generate predictions using the tokenized inputs
            print(sampled_weights_log)
            generated_ids = model.generate(
                input_ids=inputs_tokenized["input_ids"],
                attention_mask=inputs_tokenized["attention_mask"],
                max_length=512,  # Adjust as needed
                num_return_sequences=1,
                do_sample=True  # Optional: Sampling for diverse generations
            )

        # Decode generated IDs
        final_batch_predictions = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
        final_answer.extend(final_batch_predictions)
        # predictions.extend(batch_predictions)
        # references.extend(batch_references)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# /tmp/ipykernel_12555/2557256891.py:73: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# [('base_model.model.model.layers.0.self_attn.q_proj', 'default', array([[ 0.01508446,  0.00691732, -0.00206139, ..., -0.01874033,
#          0.00093975, -0.01867228],
#        [-0.01415629,  0.01682051,  0.01093652, ..., -0.03167468,
#          0.01108208, -0.00818059],
#        [ 0.00769036,  0.00204184,  0.01396344, ...,  0.00184097,
#         -0.00175042, -0.0193276 ],
#        ...,
#        [-0.01807272, -0.00940934, -0.00976349, ..., -0.00526288,
#         -0.0085222 , -0.01160066],
#        [-0.01728981, -0.03943449, -0.00465248, ...,  0.00386294,
#          0.01211404,  0.00012855],
#        [-0.01855789, -0.01124079, -0.01837003, ..., -0.00469926,
#          0.00820015, -0.0033732 ]], dtype=float32)), ('base_model.model.model.layers.0.self_attn.q_proj', 'default', array([[-0.00938235, -0.01070148, -0.00369583, ...,  0.01296223,
#         -0.00733977,  0.0155929 ],
#        [-0.00110161,  0.00825712,  0.01850528, ...,  0.00538029,
#          0.00203215,  0.00292506],
#        [ 0.01198409, -0.01477975,  0.0007006 , ...,  0.00022265,
#          0.0061757 , -0.00378681],
#        ...,
#        [-0.00960706,  0.02745407, -0.03182589, ..., -0.01244206,
#         -0.03436185,  0.00522063],
#        [-0.02998762,  0.01419145,  0.00410627, ..., -0.00861858,
#         -0.02876538, -0.01290382],
#        [-0.01385101,  0.02281146, -0.03294737, ...,  0.00555553,
#         -0.01240887, -0.0112181 ]], dtype=float32)), ('base_model.model.model.layers.0.self_attn.v_proj', 'default', array([[ 1.52646722e-02, -7.26770610e-03, -7.98424520e-03, ...,
#         -4.22004145e-03, -3.44987074e-03,  1.51630025e-02],
#        [ 8.76727328e-03, -2.35252678e-02, -3.69462301e-03, ...,
#          1.56244999e-02, -5.00020059e-03, -4.59087966e-03],
#        [-1.25124231e-02,  3.67756560e-03,  1.05994185e-02, ...,
#         -2.33851448e-02,  2.45045405e-03, -5.67256985e-03],
#        ...,
#        [ 1.47088375e-02,  2.95645371e-03,  1.49400998e-02, ...,
#          4.90992982e-03, -1.33909611e-03, -1.32235736e-02],
#        [ 6.35872316e-03,  8.60375073e-03, -1.55268013e-02, ...,
#         -1.99173484e-02,  1.53416367e-02,  2.93639768e-03],
#        [-2.27186317e-03, -2.15216205e-02,  3.33420373e-03, ...,
#         -6.57504424e-05,  1.97715051e-02, -1.95495300e-02]], dtype=float32)), ('base_model.model.model.layers.0.self_attn.v_proj', 'default', array([[-2.2411672e-02,  1.1518530e-02, -1.4626656e-03, ...,
#         -2.8133441e-03,  9.7442027e-03, -1.1489352e-02],
#        [-2.8710521e-03, -1.4655511e-03,  5.2339965e-03, ...,
#          1.3191719e-02,  5.3285309e-03,  7.6823952e-03],
#        [-1.2654739e-02,  1.3770684e-02, -3.0819557e-03, ...,
#          1.3270825e-03,  2.6819375e-03, -1.8924866e-02],
#        ...,
#        [ 3.2874697e-05, -5.7957144e-03, -1.1773773e-02, ...,
#          1.0233605e-03,  1.1875685e-02,  2.9805033e-03],
#        [ 6.7649838e-03,  8.9918012e-03, -1.1246233e-02, ...,
#         -1.0679858e-03,  1.1199592e-03, -2.0075470e-02],
#        [-1.4883491e-03, -1.3036001e-03,  5.5871704e-03, ...,
#          1.6122999e-02, -7.3254388e-04, -3.5456140e-03]], dtype=float32)), ('base_model.model.model.layers.1.self_attn.q_proj', 'default', array([[-0.01050879,  0.01315615, -0.01720494, ...,  0.01536919,
#         -0.02473398,  0.00382139],
#        [-0.01025918,  0.01089265,  0.00565477, ...,  0.00399372,
#          0.02787944, -0.02899305],
#        [-0.0198583 ,  0.01673277, -0.00290518, ..., -0.01744272,
#         -0.00364997,  0.00862756],
#        ...,
#        [ 0.00910153, -0.00469372,  0.01177066, ..., -0.02121419,
#         -0.00910972, -0.00541433],
#        [ 0.02928148,  0.00879776,  0.00420092, ..., -0.0255679 ,
#         -0.01348084,  0.00351018],
#        [-0.00209426,  0.003856  , -0.00729185, ...,  0.01991238,
#         -0.00419969, -0.03315167]], dtype=float32)), ('base_model.model.model.layers.1.self_attn.q_proj', 'default', array([[ 0.01075334, -0.00299628,  0.00641754, ..., -0.0051293 ,
#          0.00026014,  0.02305417],
#        [-0.01014832,  0.01358822,  0.0089653 , ..., -0.0079526 ,
#         -0.00362091, -0.00408866],
#        [ 0.00704376,  0.00435242,  0.0104864 , ...,  0.00697135,
#          0.01649895,  0.00892279],
#        ...,
#        [-0.0100355 , -0.01355929, -0.0006806 , ..., -0.00668514,
#         -0.00542107, -0.01327197],
#        [-0.02378305,  0.0017262 , -0.02153935, ...,  0.00146017,
#          0.00455136, -0.00988898],
#        [ 0.0093674 ,  0.00202165, -0.010163  , ..., -0.00611744,
#         -0.00139714,  0.01083957]], dtype=float32)), ('base_model.model.model.layers.1.self_attn.v_proj', 'default', array([[-6.23073429e-05,  3.72907259e-02,  2.13931799e-02, ...,
#          1.64871588e-02,  3.49535211e-03,  2.20941827e-02],
#        [-2.01412756e-03, -1.69291161e-02, -1.03104878e-02, ...,
#          8.85155052e-03, -1.23780612e-02, -3.95979965e-03],
#        [-1.32157747e-02,  8.84095207e-03,  2.40745256e-03, ...,
#         -1.88632123e-02, -3.37683735e-03,  1.45494835e-02],
#        ...,
#        [-3.30539420e-02, -1.01896105e-02, -2.31695399e-02, ...,
#          3.03835608e-04, -3.61163099e-03,  3.16234562e-03],
#        [ 1.75736006e-03,  1.10091008e-02, -1.72626507e-03, ...,
#          5.22480812e-04, -1.67638473e-02, -2.46192259e-03],
#        [ 1.94096006e-03, -1.31053897e-03, -6.62016636e-03, ...,
#          3.78747052e-03,  2.01584771e-05, -2.40374682e-03]], dtype=float32)), ('base_model.model.model.layers.1.self_attn.v_proj', 'default', array([[-0.00692424, -0.0114507 , -0.01637935, ...,  0.01865881,
#          0.00608063, -0.00497196],
#        [ 0.00636989, -0.02006884,  0.01460202, ..., -0.00114623,
#         -0.00828051, -0.02259263],
#        [ 0.00515997, -0.01051995, -0.0143053 , ..., -0.01012525,
#         -0.01862404,  0.01377186],
#        ...,
#        [ 0.00319998, -0.01345813,  0.00383667, ..., -0.00012787,
#         -0.02442771, -0.00803364],
#        [-0.00917484,  0.00992166,  0.00822383, ..., -0.00158494,
#         -0.01566532,  0.00070045],
#        [-0.00138233, -0.00301993, -0.00185012, ...,  0.00837894,
#          0.00962992,  0.02253429]], dtype=float32)), ('base_model.model.model.layers.2.self_attn.q_proj', 'default', array([[ 0.02219387,  0.01053946, -0.04656979, ...,  0.03204322,
#          0.02105526,  0.01293153],
#        [-0.01270668, -0.00690667, -0.00360821, ...,  0.00215594,
#          0.02201543,  0.01321239],
#        [ 0.0089874 ,  0.00704   ,  0.0041    , ...,  0.01997284,
#          0.00152398, -0.01329786],
#        ...,
#        [-0.00659966, -0.03529839,  0.02345995, ..., -0.00907328,
#          0.02221483,  0.00970723],
#        [ 0.01671064, -0.00653641, -0.01568598, ..., -0.00239815,
#         -0.01439874,  0.00273906],
#        [ 0.00423888, -0.02138842,  0.00260831, ..., -0.00076016,
#          0.00859482,  0.00779788]], dtype=float32)), ('base_model.model.model.layers.2.self_attn.q_proj', 'default', array([[ 0.00895058, -0.0008969 , -0.01139223, ..., -0.00077065,
#          0.01251471, -0.01067693],
#        [-0.00445645, -0.00178818, -0.01032189, ..., -0.0202455 ,
#         -0.00499618,  0.00884574],
#        [ 0.00894173,  0.00729781,  0.00656532, ...,  0.00443592,
#         -0.00091975, -0.0126042 ],
#        ...,
#        [ 0.00697741,  0.00719819, -0.00210018, ..., -0.00329724,
#         -0.01182703,  0.00680518],
#        [-0.00426673, -0.01105644, -0.00544604, ...,  0.00517338,
#          0.0112475 , -0.02164554],
#        [ 0.01012745,  0.00505397,  0.02106461, ..., -0.00686283,
#         -0.00678562,  0.00353664]], dtype=float32)), ('base_model.model.model.layers.2.self_attn.v_proj', 'default', array([[ 0.00038794, -0.0118132 ,  0.02820854, ..., -0.01730758,
#          0.0068218 ,  0.0223793 ],
#        [-0.01068634,  0.02093055,  0.00983542, ..., -0.01675207,
#         -0.00577403, -0.00283669],
#        [ 0.01501721,  0.01925748,  0.00214874, ..., -0.00744843,
#         -0.0168199 , -0.0163888 ],
#        ...,
#        [ 0.0084724 ,  0.00267232, -0.00454707, ...,  0.02045244,
#          0.01316851, -0.01662575],
#        [-0.002673  ,  0.00119205,  0.01515309, ..., -0.0103419 ,
#         -0.0092041 ,  0.02347076],
#        [ 0.01397797, -0.00546361,  0.02312816, ...,  0.01798852,
#         -0.02021706, -0.00564651]], dtype=float32)), ('base_model.model.model.layers.2.self_attn.v_proj', 'default', array([[ 0.01651206, -0.00327127, -0.00285213, ..., -0.00976665,
#         -0.00122301, -0.00064634],
#        [ 0.01368307, -0.00217968,  0.01316783, ...,  0.004125  ,
#          0.01702702, -0.00450346],
#        [ 0.01681953, -0.00751636,  0.01805073, ..., -0.00152161,
#          0.01234966, -0.01005465],
#        ...,
#        [-0.00593604,  0.00435906,  0.01461049, ..., -0.01062995,
#         -0.01802752, -0.00105034],
#        [-0.00382795, -0.00215116, -0.01475627, ..., -0.00077838,
#          0.01258213,  0.00072125],
#        [ 0.01711548, -0.01843474,  0.01393147, ..., -0.00760249,
#          0.0075371 , -0.00201902]], dtype=float32)), ('base_model.model.model.layers.3.self_attn.q_proj', 'default', array([[-0.02566996,  0.0125556 ,  0.00441807, ...,  0.01716997,
#         -0.00170662,  0.00807018],
#        [ 0.01935679, -0.00424934, -0.03134215, ...,  0.01347772,
#         -0.01149212,  0.01434243],
#        [ 0.0091615 , -0.02135   ,  0.01932969, ...,  0.01679204,
#         -0.00600238,  0.00699732],
#        ...,
#        [-0.00643069,  0.00440779,  0.00393465, ...,  0.00893867,
#         -0.01549519,  0.00326653],
#        [-0.02310088, -0.00578491,  0.00678863, ..., -0.02631542,
#          0.01071402, -0.01335258],
#        [ 0.01650066, -0.01277946, -0.00650536, ...,  0.00303069,
#         -0.01011016, -0.00400453]], dtype=float32)), ('base_model.model.model.layers.3.self_attn.q_proj', 'default', array([[ 0.00159842, -0.00176487,  0.00265403, ..., -0.00315069,
#         -0.00046986, -0.01755877],
#        [ 0.00396411,  0.00791154,  0.00042378, ..., -0.0038446 ,
#         -0.00690294,  0.01947789],
#        [ 0.00065389, -0.01182496,  0.00041967, ...,  0.00382576,
#         -0.00964995, -0.00694271],
#        ...,
#        [ 0.00401451, -0.02176729, -0.01162137, ..., -0.00787543,
#          0.00663122,  0.00541209],
#        [-0.00175362, -0.00385993, -0.00679278, ...,  0.00891638,
#          0.00083264,  0.01920975],
#        [ 0.0184148 ,  0.008762  ,  0.01886394, ..., -0.00624726,
#          0.00048707, -0.01735531]], dtype=float32)), ('base_model.model.model.layers.3.self_attn.v_proj', 'default', array([[-0.00273334, -0.0004901 ,  0.02756049, ...,  0.01211003,
#          0.00417505,  0.00095411],
#        [ 0.01468699, -0.01370712,  0.00426565, ...,  0.00395921,
#         -0.03220527, -0.00866895],
#        [-0.01062766,  0.01517037,  0.00464763, ..., -0.00519489,
#          0.00479373,  0.00615082],
#        ...,
#        [ 0.00128095, -0.0074732 , -0.01448955, ..., -0.01449021,
#          0.02104264,  0.01877501],
#        [ 0.01244673,  0.02685857,  0.00687069, ..., -0.01382549,
#          0.00014776,  0.02833916],
#        [-0.00896844, -0.03184085,  0.00544616, ...,  0.01342339,
#          0.01101934, -0.0005855 ]], dtype=float32)), ('base_model.model.model.layers.3.self_attn.v_proj', 'default', array([[ 0.00167826,  0.00785534,  0.01013862, ...,  0.00579759,
#         -0.00705027,  0.0025351 ],
#        [-0.00127765,  0.0081344 ,  0.01018917, ...,  0.0052682 ,
#          0.0051337 , -0.02848019],
#        [-0.01279136, -0.00979968, -0.00064731, ..., -0.00432067,
#          0.01028046,  0.00761788],
#        ...,
#        [ 0.01152867, -0.01745769,  0.01164532, ..., -0.00120824,
#         -0.00085635,  0.00606176],
#        [-0.01313194, -0.00747972,  0.00379017, ..., -0.00981278,
#         -0.00551839, -0.01921517],
#        [ 0.02094049,  0.02347605,  0.00635076, ...,  0.0103599 ,
#          0.00054668, -0.00732031]], dtype=float32)), ('base_model.model.model.layers.4.self_attn.q_proj', 'default', array([[-0.01133015,  0.03585292, -0.00875483, ...,  0.00141353,
#         -0.00637036, -0.02193089],
#        [-0.01633149,  0.01453519,  0.00992073, ..., -0.01668329,
#          0.01579024,  0.01320384],
#        [ 0.0087839 ,  0.00282982, -0.00710718, ...,  0.01442767,
#          0.00376535,  0.00465989],
#        ...,
#        [ 0.00743373,  0.00521061, -0.0152646 , ...,  0.01288367,
#          0.0192416 ,  0.00834639],
#        [ 0.01046555,  0.00529196,  0.01762289, ..., -0.0146163 ,
#          0.00403556,  0.01825461],
#        [ 0.01517366,  0.01967506, -0.0130259 , ..., -0.00249087,
#          0.02006235,  0.00255563]], dtype=float32)), ('base_model.model.model.layers.4.self_attn.q_proj', 'default', array([[ 6.82484917e-03, -1.54432449e-02,  6.95676031e-03, ...,
#         -1.92578994e-02,  1.86023361e-03, -1.63829122e-02],
#        [-5.04559698e-03,  2.18546996e-03,  2.23384937e-03, ...,
#          1.40653960e-02, -2.63229422e-02,  2.09266096e-02],
#        [ 1.17631536e-03, -4.11333563e-03, -6.14950713e-03, ...,
#          3.17885214e-03, -7.98370689e-03,  9.45090409e-03],
#        ...,
#        [ 9.38385539e-03, -6.74298778e-03,  6.16392680e-03, ...,
#         -1.93984695e-02, -1.05216708e-02, -1.55532993e-02],
#        [-5.40220086e-03, -2.01674122e-02, -8.26729648e-03, ...,
#          7.27467146e-03,  4.10818029e-05, -2.55877827e-03],
#        [ 1.23150945e-02, -6.47188351e-03,  1.03290249e-02, ...,
#          2.64604948e-03,  1.08845299e-02, -5.23683010e-03]], dtype=float32)), ('base_model.model.model.layers.4.self_attn.v_proj', 'default', array([[ 0.01703894, -0.00583736, -0.00193678, ..., -0.00508438,
#          0.01441266, -0.00587845],
#        [-0.00709163,  0.01284164, -0.00158107, ..., -0.0048143 ,
#         -0.00514026, -0.00200152],
#        [-0.01989932, -0.03287468,  0.00888737, ...,  0.00743648,
#          0.01065635, -0.00169329],
#        ...,
#        [ 0.01405133, -0.00301592, -0.00879938, ..., -0.00853167,
#         -0.00547107,  0.00795476],
#        [ 0.01029288, -0.01390253, -0.00387967, ..., -0.00547975,
#         -0.01405137,  0.01496157],
#        [-0.02771285, -0.00459378, -0.01083838, ..., -0.01143359,
#         -0.01555424, -0.03681263]], dtype=float32)), ('base_model.model.model.layers.4.self_attn.v_proj', 'default', array([[-0.00069   , -0.00636315, -0.00108817, ...,  0.00205405,
#         -0.01087667,  0.01021113],
#        [ 0.00980838,  0.01821599,  0.00100461, ...,  0.01300729,
#         -0.01665353, -0.00940523],
#        [ 0.00686423,  0.00861995,  0.01214531, ...,  0.00654661,
#         -0.00024319, -0.00415318],
#        ...,
#        [-0.00117791,  0.01625893,  0.0153572 , ...,  0.02015905,
#         -0.00880648,  0.00817092],
#        [-0.01568761, -0.00030206,  0.00571589, ..., -0.01736188,
#         -0.00877539, -0.00998778],
#        [ 0.00992743, -0.00128555,  0.01880153, ..., -0.00521094,
#         -0.01487672, -0.00570774]], dtype=float32)), ('base_model.model.model.layers.5.self_attn.q_proj', 'default', array([[ 7.27648148e-03, -1.22911045e-02,  3.30652902e-03, ...,
#         -3.07854004e-02, -1.06803430e-02,  1.35507039e-03],
#        [ 4.48112562e-03, -2.96033081e-03, -9.06608999e-03, ...,
#          3.18867457e-03, -1.66473910e-06, -9.88285244e-03],
#        [ 6.86292723e-03, -4.28945804e-03, -1.04250126e-02, ...,
#          1.52295195e-02, -6.15169387e-03,  1.25090443e-02],
#        ...,
#        [ 2.63129920e-02,  3.28083113e-02,  2.16120165e-02, ...,
#          1.47786168e-02,  8.78463034e-04,  3.20300367e-03],
#        [-1.10965632e-02,  2.09677089e-02, -9.54243634e-03, ...,
#          1.50962733e-02, -5.71223907e-03,  5.94328158e-03],
#        [ 9.81325656e-03, -4.56052646e-03, -1.89795122e-02, ...,
#          1.50824552e-02,  5.70167787e-03,  1.15171662e-02]], dtype=float32)), ('base_model.model.model.layers.5.self_attn.q_proj', 'default', array([[-0.04263872,  0.00646831,  0.01213543, ...,  0.00580051,
#          0.00601447, -0.00335809],
#        [ 0.01116619,  0.00570559, -0.00389508, ...,  0.00198404,
#          0.00025803,  0.01481853],
#        [-0.01903867, -0.00494725, -0.00147602, ...,  0.00371682,
#          0.00839867, -0.003246  ],
#        ...,
#        [ 0.01143814,  0.01344829, -0.00217039, ..., -0.02690406,
#          0.00264179, -0.00288133],
#        [-0.01868175,  0.00507313, -0.00869747, ..., -0.00267219,
#          0.00010995,  0.00644624],
#        [ 0.00183193, -0.00265428,  0.00448083, ..., -0.01290804,
#         -0.00515017,  0.01438394]], dtype=float32)), ('base_model.model.model.layers.5.self_attn.v_proj', 'default', array([[-0.00458567, -0.02069356,  0.00677791, ...,  0.00601227,
#         -0.01080095,  0.00084188],
#        [-0.01909827, -0.00161426, -0.03639646, ...,  0.00316341,
#         -0.01165507,  0.02786783],
#        [ 0.01152988, -0.007918  ,  0.02080534, ...,  0.00704919,
#          0.02468855, -0.01261832],
#        ...,
#        [-0.00208446, -0.01669152,  0.01635069, ...,  0.0079535 ,
#         -0.00227241,  0.0088127 ],
#        [ 0.01157152,  0.00532111,  0.02381538, ..., -0.01302861,
#         -0.01016004,  0.00843684],
#        [ 0.00427135, -0.01366368,  0.00777651, ...,  0.00543072,
#          0.00388056,  0.01931562]], dtype=float32)), ('base_model.model.model.layers.5.self_attn.v_proj', 'default', array([[-0.00512458, -0.00183452, -0.00664821, ..., -0.00016254,
#         -0.00767133, -0.00349514],
#        [ 0.00823222,  0.00704958, -0.00846514, ...,  0.00938016,
#         -0.00953383,  0.00991863],
#        [ 0.00526311,  0.00779731, -0.01139397, ...,  0.00769934,
#         -0.0141209 , -0.00599731],
#        ...,
#        [ 0.01814295,  0.00964951, -0.02154173, ...,  0.01636387,
#         -0.01282734, -0.0080877 ],
#        [ 0.01640954,  0.00637229,  0.00089147, ..., -0.00333128,
#          0.01907675, -0.00457901],
#        [-0.00450114, -0.00463296,  0.00758578, ..., -0.00210091,
#          0.01210994,  0.02074441]], dtype=float32)), ('base_model.model.model.layers.6.self_attn.q_proj', 'default', array([[-0.01307526, -0.00435744, -0.02021142, ..., -0.00279274,
#          0.00110046,  0.00026369],
#        [-0.00467291,  0.00174914,  0.00959354, ...,  0.00063187,
#         -0.02123828,  0.00193269],
#        [-0.0084614 ,  0.01854863, -0.02435412, ..., -0.01589873,
#          0.01126165, -0.01386856],
#        ...,
#        [ 0.00317451,  0.00623974,  0.01018531, ...,  0.00106142,
#         -0.02134877, -0.0214677 ],
#        [ 0.00695105, -0.00301309,  0.00515493, ..., -0.00754099,
#          0.00721362,  0.01124847],
#        [ 0.01511519, -0.00737756,  0.00776584, ...,  0.02077708,
#          0.01175928,  0.02253812]], dtype=float32)), ('base_model.model.model.layers.6.self_attn.q_proj', 'default', array([[ 0.0035799 , -0.0079703 ,  0.01963229, ...,  0.00517545,
#          0.00903912, -0.01189907],
#        [ 0.01161885, -0.01054701, -0.00073403, ..., -0.0024816 ,
#          0.00370358, -0.00420409],
#        [ 0.02410859,  0.01045007, -0.01008227, ...,  0.00819233,
#          0.01699193,  0.00766159],
#        ...,
#        [-0.00790406,  0.00354396, -0.0009373 , ...,  0.00868307,
#         -0.00286679,  0.00542769],
#        [-0.01236436,  0.00259094,  0.00701873, ...,  0.00233954,
#          0.01470206,  0.00379355],
#        [-0.02591789,  0.00063527, -0.0229735 , ...,  0.0077768 ,
#         -0.00647314,  0.00259955]], dtype=float32)), ('base_model.model.model.layers.6.self_attn.v_proj', 'default', array([[-0.01374269, -0.01861976, -0.00049302, ...,  0.02101766,
#          0.00160605, -0.0210419 ],
#        [-0.00433229,  0.02257517,  0.00310563, ...,  0.01429972,
#          0.01338344, -0.00768309],
#        [ 0.01304098, -0.04305252, -0.0101203 , ..., -0.00717531,
#          0.01590541,  0.01467797],
#        ...,
#        [ 0.01764891, -0.01256161,  0.01687464, ...,  0.02623186,
#         -0.0277817 ,  0.01244684],
#        [-0.00830887, -0.00158736, -0.01600116, ...,  0.00824019,
#         -0.00143305,  0.00360347],
#        [ 0.02246203, -0.01150002, -0.00595742, ...,  0.0063769 ,
#         -0.01689498, -0.01691071]], dtype=float32)), ('base_model.model.model.layers.6.self_attn.v_proj', 'default', array([[ 0.00195821,  0.00112416,  0.00604174, ...,  0.01431144,
#          0.00552708,  0.00385194],
#        [-0.00047419, -0.00561987,  0.01230131, ..., -0.00682987,
#         -0.00022162,  0.001161  ],
#        [-0.01082953, -0.0162647 ,  0.00212904, ..., -0.00606776,
#         -0.00175115,  0.0118673 ],
#        ...,
#        [-0.00851235, -0.00098906,  0.00569476, ..., -0.00504844,
#          0.00841562,  0.00976376],
#        [-0.01139364,  0.01404992, -0.00342897, ..., -0.0024743 ,
#          0.01058199,  0.00551648],
#        [-0.00082887,  0.00394558, -0.01021081, ...,  0.0035514 ,
#          0.01632099,  0.00183799]], dtype=float32)), ('base_model.model.model.layers.7.self_attn.q_proj', 'default', array([[ 0.0104153 ,  0.00638028, -0.00468161, ..., -0.01505576,
#          0.0108398 , -0.00352246],
#        [-0.02187167, -0.01659091, -0.01099019, ..., -0.02566772,
#         -0.0013509 , -0.00901416],
#        [-0.00199846, -0.01582603, -0.01453578, ...,  0.01147045,
#         -0.00428854, -0.00591758],
#        ...,
#        [-0.02606869, -0.00844048,  0.01779984, ..., -0.01788054,
#         -0.02078133,  0.02575481],
#        [ 0.00308971,  0.00436202,  0.01773677, ...,  0.02100785,
#         -0.00064942,  0.01396438],
#        [ 0.0011349 ,  0.02611421,  0.0058453 , ..., -0.01193245,
#         -0.01960041, -0.01297839]], dtype=float32)), ('base_model.model.model.layers.7.self_attn.q_proj', 'default', array([[-0.00206518,  0.00024442,  0.00246038, ...,  0.01361114,
#          0.0031457 ,  0.00273305],
#        [ 0.01432637, -0.01711285, -0.01002205, ..., -0.0176649 ,
#          0.02059007, -0.02662375],
#        [-0.00940937,  0.01126034, -0.00139269, ...,  0.00391823,
#          0.00115144,  0.00821869],
#        ...,
#        [-0.00877741, -0.01794746, -0.01039356, ...,  0.00538123,
#          0.0101226 ,  0.00820206],
#        [-0.00174215,  0.0211202 ,  0.01447968, ...,  0.00843308,
#          0.00580152, -0.00623985],
#        [-0.01992034,  0.00409563, -0.00924444, ...,  0.01451172,
#         -0.00662251, -0.00743316]], dtype=float32)), ('base_model.model.model.layers.7.self_attn.v_proj', 'default', array([[ 0.0006248 ,  0.00010957,  0.00412422, ...,  0.01242159,
#         -0.00187589,  0.00103048],
#        [ 0.00572408,  0.00697945, -0.00629314, ..., -0.02087546,
#          0.01477602, -0.0191554 ],
#        [ 0.00932071, -0.00493999, -0.00481776, ..., -0.00954284,
#         -0.01664248,  0.00529681],
#        ...,
#        [ 0.02302992,  0.01673949,  0.00281333, ..., -0.01192993,
#          0.00010466, -0.00205171],
#        [-0.00468293, -0.00950614, -0.00669154, ...,  0.01400251,
#          0.0036519 ,  0.01559421],
#        [ 0.02533579,  0.01590869,  0.00292868, ..., -0.01279373,
#         -0.00937601, -0.01167332]], dtype=float32)), ('base_model.model.model.layers.7.self_attn.v_proj', 'default', array([[-5.4892851e-05, -1.6236495e-02,  1.4839382e-03, ...,
#          4.3332400e-03,  3.5518291e-04, -2.2838032e-03],
#        [ 1.7810430e-02, -1.7511976e-03,  2.6375833e-03, ...,
#         -1.8302144e-02, -2.2091711e-02, -2.0208706e-03],
#        [-4.0731602e-03,  8.2546128e-03,  2.0962635e-03, ...,
#          1.1690464e-02, -6.8927971e-03, -5.9539001e-03],
#        ...,
#        [-6.1603482e-03,  8.5989945e-03, -4.3825284e-03, ...,
#         -3.6346361e-03,  6.4696567e-03,  1.7533360e-02],
#        [ 1.6466747e-03, -4.2465646e-03, -7.8081214e-03, ...,
#         -8.1586782e-03,  4.3396931e-03,  4.7099856e-03],
#        [-4.9427024e-04,  2.1912055e-02,  1.2478210e-02, ...,
#          4.7744391e-03,  1.3317287e-02,  1.9191129e-02]], dtype=float32)), ('base_model.model.model.layers.8.self_attn.q_proj', 'default', array([[-3.0784602e-03, -2.1517869e-02,  1.2910507e-02, ...,
#          3.0261553e-03,  1.5982356e-02, -1.0158325e-02],
#        [ 2.7341764e-02,  1.1068766e-02,  5.3006830e-03, ...,
#          6.7953481e-03,  7.9595270e-03, -1.3853360e-02],
#        [-2.6839320e-05,  2.0195562e-02, -7.5782458e-03, ...,
#         -3.3829010e-03,  3.9088079e-03, -2.1392815e-02],
#        ...,
#        [ 2.2833264e-03,  2.5220238e-02, -5.6301723e-03, ...,
#          2.0218007e-03,  9.8085478e-03,  1.5976718e-02],
#        [ 2.0709489e-02, -1.7417619e-02,  2.1094348e-02, ...,
#         -2.3307886e-02, -1.3892768e-02,  2.8167551e-02],
#        [ 1.1322910e-02, -5.1722368e-03,  5.2381065e-03, ...,
#         -8.2867425e-03, -2.7068742e-03,  3.3915471e-03]], dtype=float32)), ('base_model.model.model.layers.8.self_attn.q_proj', 'default', array([[ 0.0133817 , -0.02570504,  0.00766105, ...,  0.01117563,
#          0.00651354,  0.00128561],
#        [ 0.01437194,  0.00350132,  0.00329751, ...,  0.00113255,
#         -0.00861651,  0.00269998],
#        [ 0.01069501, -0.005482  , -0.00406063, ..., -0.00930382,
#         -0.0133791 ,  0.01253451],
#        ...,
#        [-0.007714  , -0.00988614, -0.00323533, ...,  0.01198855,
#         -0.00883067, -0.00875813],
#        [-0.02373613, -0.00115546, -0.00625932, ..., -0.0041022 ,
#         -0.00240684, -0.00336905],
#        [-0.00559423, -0.01946705, -0.00808682, ..., -0.00189368,
#          0.00503921,  0.00574285]], dtype=float32)), ('base_model.model.model.layers.8.self_attn.v_proj', 'default', array([[-2.0090858e-02,  7.3808166e-03, -2.0414023e-03, ...,
#          1.1582980e-02,  1.0828692e-03,  3.0531832e-03],
#        [-2.3545779e-02,  2.0635288e-02,  5.4689590e-05, ...,
#         -9.5280074e-03, -3.2259030e-03, -2.1021254e-02],
#        [-1.3613426e-03, -1.2327984e-03,  2.4823233e-02, ...,
#         -3.6694931e-03,  2.0305194e-02, -1.7055489e-02],
#        ...,
#        [-1.6064256e-02,  5.8845454e-03, -1.2276241e-03, ...,
#         -2.0895910e-02,  9.7970339e-03, -2.7254984e-02],
#        [ 4.9916273e-03,  4.3850807e-03,  2.4948491e-02, ...,
#         -5.8402494e-03, -2.0039761e-02,  2.1799730e-02],
#        [ 3.7882095e-03, -1.4499397e-02,  2.6934827e-03, ...,
#          8.1770495e-03,  2.2947941e-02, -1.1996820e-02]], dtype=float32)), ('base_model.model.model.layers.8.self_attn.v_proj', 'default', array([[ 0.00785592,  0.00487524,  0.00363555, ...,  0.00060565,
#         -0.00323747, -0.01895335],
#        [ 0.01545625, -0.01909249, -0.00648318, ..., -0.01467492,
#         -0.00017009,  0.01510783],
#        [ 0.00720122, -0.01320081,  0.01193657, ..., -0.00468374,
#          0.0019602 , -0.00765229],
#        ...,
#        [ 0.01296639,  0.01098343, -0.00060799, ...,  0.01407353,
#         -0.01185886,  0.00336847],
#        [ 0.00012886, -0.00082393, -0.01611613, ...,  0.00099661,
#         -0.0117446 ,  0.00301974],
#        [-0.01229932, -0.0148561 ,  0.00284282, ..., -0.00100111,
#          0.01760639, -0.00784038]], dtype=float32)), ('base_model.model.model.layers.9.self_attn.q_proj', 'default', array([[ 0.00107215,  0.02223917, -0.0010375 , ..., -0.01410975,
#          0.03867015, -0.03607159],
#        [-0.00073959,  0.00091365, -0.00550993, ..., -0.00340644,
#          0.0068118 ,  0.01335617],
#        [-0.01192615, -0.01126987,  0.00426058, ...,  0.00202889,
#         -0.01359987,  0.01315632],
#        ...,
#        [ 0.02670053, -0.04378516,  0.0176819 , ..., -0.00758958,
#          0.00641024,  0.02659084],
#        [ 0.00232475,  0.00834941,  0.00595949, ...,  0.00278391,
#          0.00920563,  0.00955414],
#        [ 0.01121707, -0.00255405,  0.01151995, ..., -0.01809257,
#         -0.00244127,  0.00178159]], dtype=float32)), ('base_model.model.model.layers.9.self_attn.q_proj', 'default', array([[-2.13774573e-03,  8.35953094e-03,  5.28909918e-03, ...,
#          1.28954705e-02, -1.47809442e-02, -1.04429922e-03],
#        [ 1.59434453e-02,  5.00893919e-03,  1.29068121e-02, ...,
#         -4.61688917e-03,  9.92125832e-03,  1.43743269e-02],
#        [ 2.81938631e-03,  1.24408957e-02,  3.60802514e-04, ...,
#         -2.28730422e-02,  3.81761440e-03,  1.52304000e-03],
#        ...,
#        [-7.67383445e-03, -1.12050436e-02, -4.16572718e-03, ...,
#          1.05844601e-03, -1.81957521e-02, -1.26882177e-03],
#        [ 4.61732270e-05,  3.43419099e-03,  1.66857596e-02, ...,
#          1.95713085e-03, -6.85572065e-03,  1.19467694e-02],
#        [-7.12692318e-03, -1.45725887e-02, -3.37543571e-03, ...,
#          8.62734206e-03,  6.44158199e-03, -1.17126689e-03]], dtype=float32)), ('base_model.model.model.layers.9.self_attn.v_proj', 'default', array([[-2.4927799e-03, -1.8948209e-02,  5.8261459e-03, ...,
#         -9.8459609e-03, -9.9340277e-03,  1.6348146e-02],
#        [ 2.3720847e-03, -4.4438248e-03, -2.4192750e-02, ...,
#         -1.3954982e-02, -3.4807716e-05,  1.9503938e-02],
#        [-3.7058396e-03,  1.4492521e-02,  1.5533320e-03, ...,
#         -1.3828693e-02,  2.3339890e-02, -1.0542851e-03],
#        ...,
#        [ 1.2880157e-02,  5.6693791e-03, -6.0912389e-03, ...,
#          8.3291773e-03,  7.7910591e-03,  1.0183066e-02],
#        [ 2.3480300e-03, -2.5211588e-02, -6.5190475e-03, ...,
#         -1.6703788e-02, -1.4632618e-02,  5.3543504e-04],
#        [ 2.5867783e-03, -1.7605336e-02, -1.2198047e-02, ...,
#          6.0593346e-03, -2.7792496e-03,  1.4053811e-02]], dtype=float32)), ('base_model.model.model.layers.9.self_attn.v_proj', 'default', array([[ 0.01283653, -0.00658553, -0.01403126, ...,  0.01155367,
#          0.00351622, -0.0075547 ],
#        [ 0.00388835, -0.00726503, -0.00536928, ..., -0.032213  ,
#         -0.00095712, -0.00308634],
#        [ 0.01013858,  0.00963348, -0.00974038, ..., -0.00474343,
#         -0.00201069, -0.01114403],
#        ...,
#        [ 0.0138453 , -0.00433351,  0.00212548, ..., -0.00769891,
#         -0.00492273,  0.00756816],
#        [ 0.02518709,  0.0036665 ,  0.00792565, ..., -0.00167477,
#         -0.00403423,  0.00922296],
#        [-0.00344442,  0.01215944,  0.00338342, ..., -0.00386554,
#          0.00659077,  0.00253803]], dtype=float32)), ('base_model.model.model.layers.10.self_attn.q_proj', 'default', array([[ 0.00274492, -0.01979012,  0.01286616, ...,  0.0274916 ,
#         -0.00915646,  0.00139538],
#        [ 0.01612426,  0.01797915,  0.01219963, ..., -0.0168899 ,
#          0.02226367, -0.01551424],
#        [ 0.00492233,  0.00683287,  0.01351689, ..., -0.02234786,
#         -0.02513193, -0.0118475 ],
#        ...,
#        [ 0.0127205 ,  0.01917511,  0.00450807, ..., -0.00300884,
#         -0.01642414, -0.01587241],
#        [ 0.02459953, -0.00093233, -0.01636456, ..., -0.01763507,
#         -0.01978144,  0.00156113],
#        [ 0.00896579, -0.028035  , -0.01000392, ...,  0.00825604,
#          0.00291342,  0.01316451]], dtype=float32)), ('base_model.model.model.layers.10.self_attn.q_proj', 'default', array([[-0.00336326,  0.00218378,  0.01028679, ..., -0.02533911,
#         -0.00478065, -0.00720035],
#        [-0.00535551, -0.00711236, -0.00310334, ...,  0.00399906,
#         -0.00610709, -0.01207181],
#        [ 0.00298384, -0.00822554,  0.00084073, ...,  0.02048869,
#         -0.01495958,  0.00883124],
#        ...,
#        [-0.00626933,  0.00100395,  0.00374727, ..., -0.00106115,
#         -0.00669503,  0.01143656],
#        [ 0.00726214,  0.01318031, -0.02133364, ..., -0.00482369,
#         -0.01989434,  0.00349674],
#        [ 0.00134103, -0.00106773, -0.01680223, ...,  0.00130522,
#          0.01382372, -0.00717874]], dtype=float32)), ('base_model.model.model.layers.10.self_attn.v_proj', 'default', array([[-0.01723862, -0.01024805, -0.00184933, ...,  0.00964071,
#         -0.03297497, -0.00564743],
#        [ 0.00390171, -0.00738221,  0.01689433, ...,  0.0152439 ,
#         -0.01883236, -0.0242669 ],
#        [-0.00477744, -0.00992776, -0.00946263, ..., -0.00769455,
#          0.01577314,  0.00119728],
#        ...,
#        [ 0.00780774, -0.01862761,  0.00261111, ..., -0.00234028,
#          0.00235407, -0.01503916],
#        [ 0.01168204, -0.007327  , -0.01708366, ...,  0.00909213,
#          0.00282703, -0.00153361],
#        [-0.0208132 ,  0.01505588,  0.00839868, ..., -0.01204414,
#         -0.00326854,  0.00936903]], dtype=float32)), ('base_model.model.model.layers.10.self_attn.v_proj', 'default', array([[ 0.00999495, -0.01939601,  0.00607531, ..., -0.00407847,
#         -0.01582984,  0.00456074],
#        [-0.01234349,  0.00616042, -0.00561825, ...,  0.00180256,
#         -0.02091699, -0.00319317],
#        [-0.00864009,  0.0095084 ,  0.00472904, ...,  0.00814699,
#          0.01248854, -0.01975839],
#        ...,
#        [-0.01395375,  0.00027567, -0.00044478, ...,  0.00549915,
#          0.01170303,  0.00967605],
#        [-0.00562482, -0.00777834,  0.00340757, ...,  0.00121891,
#          0.01284044,  0.0120068 ],
#        [-0.02181634, -0.01145135,  0.01234446, ..., -0.01303039,
#          0.00172389,  0.00328486]], dtype=float32)), ('base_model.model.model.layers.11.self_attn.q_proj', 'default', array([[ 0.00972465,  0.01219257,  0.00727225, ..., -0.00325369,
#         -0.00288338,  0.00758071],
#        [ 0.00766743,  0.01091507,  0.01720479, ..., -0.00227669,
#          0.02210605, -0.0058701 ],
#        [-0.00165958,  0.00118794,  0.00850698, ...,  0.02573913,
#          0.01098963,  0.00945447],
#        ...,
#        [ 0.00058513,  0.01561256,  0.04573873, ...,  0.00568556,
#          0.02126177,  0.01622964],
#        [-0.01061295, -0.01540675,  0.00621107, ...,  0.00068026,
#         -0.01301016, -0.00253878],
#        [-0.03182874,  0.01450733,  0.02916826, ...,  0.00915984,
#          0.00766102, -0.0120983 ]], dtype=float32)), ('base_model.model.model.layers.11.self_attn.q_proj', 'default', array([[ 0.00470494,  0.00306168, -0.00018516, ..., -0.00881231,
#         -0.00903557,  0.00574069],
#        [-0.00606528, -0.00789038,  0.01076873, ..., -0.00365779,
#         -0.00755837,  0.02401442],
#        [ 0.0077801 ,  0.02543673, -0.00691647, ...,  0.00152624,
#          0.00130316, -0.00485685],
#        ...,
#        [-0.00979807,  0.01707451, -0.00446414, ..., -0.00343607,
#          0.00697399, -0.01524238],
#        [-0.00377435, -0.00920548, -0.02182599, ...,  0.01357756,
#          0.00345028,  0.01899199],
#        [ 0.00425504,  0.01635886, -0.00792212, ...,  0.01947845,
#         -0.00218577,  0.00987713]], dtype=float32)), ('base_model.model.model.layers.11.self_attn.v_proj', 'default', array([[-8.41547549e-03, -1.59961730e-02,  9.99015756e-05, ...,
#          4.24542278e-03,  2.78753042e-03, -4.12179530e-03],
#        [-6.17765542e-03,  5.39165735e-03, -1.41862426e-02, ...,
#          2.11067814e-02,  2.06723064e-03, -4.17020731e-03],
#        [-1.05047449e-02,  1.05410106e-02, -5.80074172e-03, ...,
#          7.40318187e-03, -7.18381628e-03, -1.09749837e-02],
#        ...,
#        [ 4.09815274e-03, -1.28166061e-02, -1.54688768e-03, ...,
#         -1.00866864e-02,  2.76094768e-04, -2.09302586e-02],
#        [-9.85212810e-03,  1.92626510e-02,  1.61529817e-02, ...,
#          1.96761973e-02,  3.55811464e-03, -4.89558280e-03],
#        [ 4.22466081e-04, -1.19607355e-02, -2.05916464e-02, ...,
#          4.66006668e-03, -1.28897885e-02, -1.04541499e-02]], dtype=float32)), ('base_model.model.model.layers.11.self_attn.v_proj', 'default', array([[ 0.02233106,  0.01205046, -0.01253824, ..., -0.00302614,
#         -0.01219378, -0.00825079],
#        [-0.00358982,  0.00268751,  0.02731785, ...,  0.0113759 ,
#          0.00558249, -0.00406054],
#        [ 0.00418506,  0.00252541, -0.01579867, ...,  0.00491383,
#         -0.00128898, -0.00031483],
#        ...,
#        [ 0.00130652,  0.00050681, -0.0080258 , ..., -0.00063269,
#         -0.0063471 , -0.00206248],
#        [ 0.00461327,  0.00803082, -0.01911201, ..., -0.0219285 ,
#          0.00182374,  0.01645094],
#        [-0.01748968, -0.02130693,  0.00172796, ...,  0.01352943,
#          0.0060521 , -0.00326826]], dtype=float32)), ('base_model.model.model.layers.12.self_attn.q_proj', 'default', array([[-0.00813938, -0.01557212, -0.00657554, ...,  0.00472792,
#         -0.00377872, -0.00660001],
#        [-0.00363813,  0.00360896, -0.0077469 , ..., -0.0127011 ,
#         -0.00577414, -0.01515829],
#        [ 0.01135107, -0.02271382, -0.0128478 , ..., -0.01790974,
#         -0.00308197,  0.00594082],
#        ...,
#        [-0.00355429, -0.00527821,  0.01261018, ..., -0.00400178,
#         -0.0030059 ,  0.00018643],
#        [-0.01554876, -0.0024748 , -0.0151242 , ..., -0.0014109 ,
#         -0.0056851 , -0.00163487],
#        [-0.01657526, -0.00170357, -0.00859081, ..., -0.0203721 ,
#          0.02467203,  0.02173693]], dtype=float32)), ('base_model.model.model.layers.12.self_attn.q_proj', 'default', array([[ 0.01115261,  0.00788857, -0.00852136, ...,  0.00459741,
#         -0.00232494, -0.01996847],
#        [-0.00593331, -0.00257482, -0.01464017, ..., -0.0267563 ,
#          0.01075712, -0.00735188],
#        [-0.02059343, -0.00731097, -0.01393504, ..., -0.00457494,
#          0.00976709,  0.00332827],
#        ...,
#        [-0.00798604, -0.00754344,  0.00821085, ..., -0.02301153,
#         -0.00892311,  0.01408553],
#        [-0.00142485, -0.00016224,  0.01352236, ..., -0.00964539,
#          0.0152664 , -0.0175343 ],
#        [-0.00454673, -0.00507781, -0.01004006, ..., -0.01007666,
#          0.0153379 , -0.00013676]], dtype=float32)), ('base_model.model.model.layers.12.self_attn.v_proj', 'default', array([[-3.0936833e-02, -3.4468018e-03, -1.6900919e-02, ...,
#          1.3387494e-02, -5.2804835e-03, -7.7890269e-03],
#        [ 9.5681101e-03,  1.1017986e-02, -1.4829697e-02, ...,
#         -1.7518068e-02,  6.0413443e-03, -2.5089523e-02],
#        [-2.2797290e-02,  3.1712665e-03,  2.0644013e-03, ...,
#         -2.7048808e-02, -2.0990036e-03,  6.3741580e-05],
#        ...,
#        [ 3.7105372e-03, -1.0509756e-02,  2.4483602e-02, ...,
#         -1.5390776e-02, -2.6667411e-03,  1.6568694e-02],
#        [ 6.5016253e-03,  1.2682527e-02,  7.8144213e-03, ...,
#          3.2074079e-03, -1.3878645e-02,  9.8195707e-04],
#        [ 5.3575896e-03,  1.5120725e-03,  3.4900801e-03, ...,
#          2.6690241e-02,  3.0063512e-03,  1.0166107e-02]], dtype=float32)), ('base_model.model.model.layers.12.self_attn.v_proj', 'default', array([[-0.00091808, -0.00704572, -0.00774716, ...,  0.02272634,
#          0.00409044,  0.00540234],
#        [ 0.00013418,  0.00491622,  0.00918177, ..., -0.00828011,
#          0.00395018, -0.00474031],
#        [ 0.00487855, -0.00348225, -0.00656093, ..., -0.00530184,
#         -0.00124316,  0.01340426],
#        ...,
#        [ 0.0237341 ,  0.00702783,  0.01443129, ...,  0.00311359,
#         -0.00812455, -0.00276904],
#        [ 0.01534564,  0.016025  ,  0.02535998, ...,  0.0053881 ,
#         -0.00191118, -0.00354832],
#        [ 0.00066104, -0.01426747, -0.00745311, ...,  0.00306708,
#          0.00787854,  0.00164472]], dtype=float32)), ('base_model.model.model.layers.13.self_attn.q_proj', 'default', array([[ 0.0260537 ,  0.01721369, -0.00460983, ...,  0.00257604,
#         -0.00050259,  0.00117472],
#        [ 0.00913933, -0.00890615,  0.03235153, ...,  0.01399644,
#         -0.01477484, -0.00804568],
#        [-0.028054  , -0.01260939, -0.01199186, ..., -0.0086479 ,
#         -0.01030815,  0.00892782],
#        ...,
#        [-0.01111118,  0.02601706,  0.01087632, ..., -0.02269382,
#         -0.00318807,  0.02918597],
#        [-0.00315716,  0.02097717,  0.01346401, ...,  0.00155801,
#         -0.00182649,  0.00960528],
#        [ 0.00138519, -0.01149018, -0.0101661 , ..., -0.02431   ,
#         -0.01568196, -0.01178878]], dtype=float32)), ('base_model.model.model.layers.13.self_attn.q_proj', 'default', array([[ 8.93246755e-03, -1.16978306e-04,  1.48526337e-02, ...,
#          1.01238908e-03, -1.80927292e-02, -6.55918103e-03],
#        [ 5.21959597e-03,  9.64911655e-03, -7.98224355e-04, ...,
#         -5.72730228e-03,  9.74649936e-03,  1.47973830e-02],
#        [-1.35754282e-02, -4.54595592e-03, -1.27398260e-02, ...,
#         -5.68694551e-04,  1.55163612e-02, -8.31212290e-03],
#        ...,
#        [ 1.47559133e-03, -1.01687275e-02,  2.61878595e-05, ...,
#          8.33691936e-03,  2.24981103e-02, -2.16475725e-02],
#        [-1.44803408e-03,  2.26038299e-03, -1.62024386e-02, ...,
#         -3.67050315e-03,  1.63246989e-02, -7.27642467e-03],
#        [ 2.37288140e-03,  1.03321522e-02,  1.07947038e-02, ...,
#         -2.97424127e-03,  7.98411085e-04, -6.31245412e-03]], dtype=float32)), ('base_model.model.model.layers.13.self_attn.v_proj', 'default', array([[-1.4972175e-02, -2.4327038e-02,  6.5327929e-03, ...,
#          1.3635956e-02, -2.5046287e-02,  2.7959945e-02],
#        [ 9.2053106e-03,  4.6834052e-03, -3.5458147e-03, ...,
#         -6.5654516e-05, -1.6934536e-03,  1.3182219e-03],
#        [-3.0098325e-03,  9.7095477e-04, -7.4930699e-03, ...,
#         -4.6165292e-03,  2.1830644e-04,  1.8558111e-02],
#        ...,
#        [ 9.3440097e-03, -4.5628473e-03,  1.9117516e-02, ...,
#         -9.9623110e-03, -9.2969975e-03,  8.6333612e-03],
#        [-1.1818435e-02, -7.0369761e-03,  1.5123770e-02, ...,
#          8.1334775e-03, -3.4667016e-03,  3.1772070e-05],
#        [-1.3042171e-02,  7.5556757e-03,  1.7001316e-02, ...,
#          8.6824782e-04,  2.6768615e-02,  9.1598015e-03]], dtype=float32)), ('base_model.model.model.layers.13.self_attn.v_proj', 'default', array([[-2.99767219e-03,  1.45599414e-02, -1.46042020e-03, ...,
#          1.13761425e-02, -5.63253649e-04,  3.24314740e-03],
#        [ 6.07493985e-03, -1.39946467e-04,  2.45105196e-03, ...,
#          1.30215744e-02, -7.93207530e-03,  3.56962136e-03],
#        [ 1.54364686e-02, -1.09054670e-02, -1.15091717e-02, ...,
#         -4.31265170e-03,  4.77118511e-03,  3.06775654e-03],
#        ...,
#        [ 1.69157470e-03, -8.87712650e-03, -6.41996739e-03, ...,
#          1.57234240e-02, -2.33452069e-03, -6.76055485e-03],
#        [-1.37516223e-02,  8.35426245e-03, -5.56330197e-03, ...,
#          1.36522576e-05,  6.94055110e-04,  1.15504311e-02],
#        [ 2.09649489e-03, -7.52068707e-04, -1.03284614e-02, ...,
#         -1.85844805e-02,  1.28677646e-02, -5.00037381e-03]], dtype=float32)), ('base_model.model.model.layers.14.self_attn.q_proj', 'default', array([[ 0.00668769,  0.01685728,  0.01225964, ..., -0.00436729,
#         -0.03536738, -0.00976757],
#        [-0.0041762 , -0.02977589,  0.00105052, ..., -0.00339946,
#         -0.0070367 , -0.02233061],
#        [ 0.01439152, -0.01531761, -0.01421269, ...,  0.00495443,
#          0.00772552, -0.0218252 ],
#        ...,
#        [ 0.0308106 ,  0.0325843 ,  0.00360218, ..., -0.0075922 ,
#          0.00480403, -0.02843631],
#        [-0.00031287, -0.02352992,  0.01216423, ...,  0.00099273,
#          0.02790465,  0.01060568],
#        [-0.00440919, -0.0067237 ,  0.00177825, ...,  0.00058029,
#         -0.02949813,  0.00781681]], dtype=float32)), ('base_model.model.model.layers.14.self_attn.q_proj', 'default', array([[-0.01128677, -0.00015118, -0.00862855, ...,  0.00769246,
#          0.01015193,  0.02185873],
#        [-0.00827896, -0.00375818, -0.00224028, ..., -0.00809753,
#         -0.00581394,  0.01131246],
#        [-0.00208331, -0.00922742,  0.00231902, ...,  0.00416124,
#         -0.00787529, -0.01003199],
#        ...,
#        [ 0.00472513, -0.00317418, -0.00353223, ..., -0.00211971,
#         -0.0132411 ,  0.01979682],
#        [-0.01114159, -0.00297285, -0.00179423, ..., -0.00951456,
#         -0.0046552 , -0.01333654],
#        [ 0.01699712, -0.00443612, -0.00799608, ...,  0.01587109,
#         -0.00833166, -0.01792701]], dtype=float32)), ('base_model.model.model.layers.14.self_attn.v_proj', 'default', array([[-0.0041154 , -0.00575851,  0.01772192, ..., -0.02901628,
#         -0.0156857 , -0.01031862],
#        [ 0.00142194, -0.00480888,  0.01042587, ..., -0.01891414,
#          0.01478297, -0.0048725 ],
#        [-0.01323045, -0.02115273,  0.01021992, ..., -0.0296086 ,
#          0.00092384, -0.00597389],
#        ...,
#        [-0.00072512, -0.00067592, -0.01326732, ..., -0.00052193,
#          0.03358252, -0.02816383],
#        [ 0.00349275, -0.01435195, -0.00520027, ..., -0.01681344,
#         -0.02049568, -0.01550687],
#        [ 0.01628665,  0.00554243,  0.02376482, ...,  0.00367139,
#         -0.01664531,  0.00888897]], dtype=float32)), ('base_model.model.model.layers.14.self_attn.v_proj', 'default', array([[ 0.02454794, -0.00668825,  0.00486745, ..., -0.00187185,
#         -0.00095802, -0.00455182],
#        [-0.00100157, -0.0087644 ,  0.00395034, ...,  0.00560608,
#         -0.01552975, -0.01521622],
#        [ 0.00013942, -0.00228407,  0.02041877, ...,  0.01798323,
#         -0.0006007 , -0.00306614],
#        ...,
#        [-0.01009422, -0.00348258,  0.00301269, ..., -0.00905728,
#         -0.00075701,  0.01551505],
#        [ 0.00186671, -0.00454752, -0.00934007, ...,  0.01505271,
#         -0.01614577, -0.00647197],
#        [ 0.00173972, -0.01254033,  0.0021517 , ..., -0.00264264,
#         -0.00178439, -0.00760463]], dtype=float32)), ('base_model.model.model.layers.15.self_attn.q_proj', 'default', array([[ 0.01243725,  0.00868177, -0.01111358, ..., -0.01509535,
#          0.01038199, -0.01545031],
#        [-0.01072458, -0.00652778, -0.00901389, ...,  0.000412  ,
#          0.00612116, -0.01441671],
#        [-0.00934839, -0.00959047,  0.00336643, ..., -0.00799535,
#          0.00412483, -0.00502812],
#        ...,
#        [-0.00445835,  0.00045149,  0.02003621, ...,  0.00874273,
#          0.00623987,  0.0173859 ],
#        [-0.0207747 ,  0.01133715, -0.03136815, ...,  0.00582602,
#         -0.01371885, -0.00704663],
#        [ 0.01335225,  0.01356776, -0.00381756, ..., -0.00030716,
#          0.00191119,  0.02694895]], dtype=float32)), ('base_model.model.model.layers.15.self_attn.q_proj', 'default', array([[ 0.01770914,  0.00322474, -0.00333586, ..., -0.00178356,
#         -0.00217929, -0.00507922],
#        [-0.00464958,  0.01317815, -0.01348671, ..., -0.00447688,
#          0.0127688 ,  0.00080955],
#        [ 0.00930959, -0.00943067, -0.00423098, ...,  0.00037647,
#         -0.00776492,  0.01147002],
#        ...,
#        [-0.00355134,  0.00779715, -0.00683622, ..., -0.01168699,
#         -0.00435924,  0.01647897],
#        [-0.021703  ,  0.00066534, -0.00670028, ..., -0.01654721,
#          0.02783099, -0.02293982],
#        [-0.00177185,  0.007966  ,  0.00298679, ...,  0.00711818,
#         -0.00269504,  0.00669085]], dtype=float32)), ('base_model.model.model.layers.15.self_attn.v_proj', 'default', array([[ 0.00745873, -0.03395611, -0.00427293, ...,  0.02283746,
#          0.00653273, -0.00135308],
#        [ 0.00956302, -0.01998085, -0.00251077, ..., -0.01867229,
#         -0.01657542,  0.00515437],
#        [ 0.00734055, -0.00244029,  0.01157537, ...,  0.02117103,
#          0.0170701 , -0.02611765],
#        ...,
#        [-0.02427482,  0.01376953,  0.01046155, ..., -0.00165738,
#         -0.01576713, -0.01445022],
#        [ 0.01476337,  0.01346091,  0.00676288, ...,  0.01824702,
#          0.02120341,  0.01600806],
#        [ 0.01451987,  0.0046329 ,  0.01950232, ...,  0.00240738,
#         -0.01224715,  0.01242957]], dtype=float32)), ('base_model.model.model.layers.15.self_attn.v_proj', 'default', array([[ 0.00193096, -0.01796095,  0.00938623, ..., -0.00353571,
#          0.00294982, -0.00047043],
#        [-0.01032559, -0.00091997, -0.0140698 , ..., -0.00550492,
#         -0.00372852,  0.01153647],
#        [-0.01268203,  0.00600292, -0.00307386, ...,  0.00688583,
#         -0.0060616 , -0.00489802],
#        ...,
#        [ 0.00502987,  0.00681193,  0.00705563, ..., -0.00852959,
#          0.00325633, -0.00336894],
#        [-0.00577846, -0.00102648, -0.00080409, ..., -0.00569309,
#         -0.02481759,  0.00623018],
#        [-0.01205911, -0.000873  ,  0.00100885, ..., -0.01347074,
#          0.01340567,  0.00015704]], dtype=float32)), ('base_model.model.model.layers.16.self_attn.q_proj', 'default', array([[ 0.00367881,  0.00149109, -0.0108124 , ..., -0.01162792,
#         -0.00671822, -0.00474584],
#        [ 0.01001401, -0.01889689,  0.01135931, ...,  0.00829118,
#          0.0119558 ,  0.00654011],
#        [-0.00913498,  0.0074882 , -0.00143461, ..., -0.02193617,
#         -0.02056468,  0.00967649],
#        ...,
#        [ 0.00366272,  0.00505744, -0.01410399, ...,  0.00551925,
#         -0.00601949,  0.01005402],
#        [-0.01095806, -0.02958673,  0.01075724, ..., -0.01056475,
#         -0.01147731,  0.03679601],
#        [-0.0020929 , -0.00699641,  0.01675531, ..., -0.01485083,
#          0.00946998,  0.00232479]], dtype=float32)), ('base_model.model.model.layers.16.self_attn.q_proj', 'default', array([[-1.60586648e-02, -6.80974731e-03,  2.54281331e-04, ...,
#          1.50040966e-02, -7.86712673e-03,  1.02581922e-02],
#        [-1.05078137e-02, -6.37124805e-03,  7.01561011e-03, ...,
#         -8.10468663e-03,  2.24219682e-03,  6.38056081e-05],
#        [-1.72814298e-02, -1.55056855e-02,  6.33302983e-03, ...,
#         -2.17373352e-02, -1.40196299e-02, -5.31735877e-03],
# ...
#         -0.00484243, -0.01137838],
#        [-0.01802028, -0.0089263 , -0.0095077 , ..., -0.00529158,
#         -0.00573377, -0.01317992],
#        [-0.01512763, -0.00291987,  0.01482947, ...,  0.01873447,
#         -0.0047146 ,  0.01490032]], dtype=float32)), ('base_model.model.model.layers.26.self_attn.v_proj', 'default', array([[-0.01203893, -0.00716233,  0.00919468, ..., -0.01653783,
#          0.01967127, -0.0020319 ],
#        [ 0.04105966,  0.00532576, -0.00161712, ..., -0.01816792,
#         -0.00644115, -0.02338628],
#        [ 0.00160092,  0.00712734,  0.00974553, ..., -0.02450443,
#          0.02137045, -0.00674999],
#        ...,
#        [-0.00956792,  0.04234729, -0.00430541, ...,  0.01519857,
#          0.00634194,  0.00507912],
#        [-0.00138652,  0.0234111 , -0.02236061, ..., -0.02871088,
#         -0.00125306, -0.01879143],
#        [ 0.00691029,  0.01317606,  0.00642134, ...,  0.0059497 ,
#          0.01831215, -0.00390816]], dtype=float32)), ('base_model.model.model.layers.26.self_attn.v_proj', 'default', array([[-0.0016649 , -0.00607966,  0.01757464, ..., -0.0002704 ,
#         -0.00969181,  0.00147536],
#        [ 0.00278509, -0.01479162, -0.00550331, ...,  0.02011571,
#         -0.00496678,  0.00981475],
#        [ 0.01066468, -0.00524032,  0.00586137, ...,  0.01932811,
#         -0.01300653, -0.00812567],
#        ...,
#        [-0.01492252,  0.00153133, -0.00721322, ..., -0.00732838,
#         -0.00948346,  0.0007989 ],
#        [-0.00148245,  0.00518725,  0.01766916, ...,  0.00663269,
#          0.01600183, -0.01320438],
#        [ 0.00763384,  0.00726179,  0.00743087, ..., -0.00182898,
#         -0.00057104,  0.00385968]], dtype=float32)), ('base_model.model.model.layers.27.self_attn.q_proj', 'default', array([[ 0.01083018,  0.00441029, -0.00813854, ...,  0.01028345,
#         -0.01509002,  0.00013134],
#        [-0.00632699, -0.02769373, -0.00403718, ...,  0.01016031,
#         -0.01375381,  0.01165364],
#        [-0.01311693,  0.00235129, -0.02808612, ..., -0.00475174,
#         -0.01369748,  0.0021444 ],
#        ...,
#        [ 0.01177976, -0.01591615, -0.0263518 , ...,  0.0089008 ,
#          0.01748426, -0.00334028],
#        [-0.00479029,  0.02215191, -0.01730685, ..., -0.02640164,
#         -0.01683486, -0.02650343],
#        [ 0.02205676, -0.00131169, -0.00575687, ..., -0.00817107,
#         -0.02294309, -0.01372809]], dtype=float32)), ('base_model.model.model.layers.27.self_attn.q_proj', 'default', array([[-0.01247043,  0.00138161, -0.00025007, ...,  0.01752423,
#          0.00924618, -0.01363278],
#        [-0.00149642, -0.00885233, -0.00669941, ..., -0.00999132,
#          0.01531653,  0.00036195],
#        [ 0.00620958, -0.00669651, -0.01109606, ..., -0.00293175,
#          0.00355206,  0.02091917],
#        ...,
#        [ 0.00478793, -0.00395199, -0.0125832 , ...,  0.00952102,
#          0.01578398,  0.00630815],
#        [-0.00560044,  0.01240434,  0.00535066, ..., -0.00320003,
#          0.00677407, -0.00796758],
#        [ 0.00138494,  0.00075427,  0.01731496, ..., -0.00702729,
#         -0.00332025, -0.01569006]], dtype=float32)), ('base_model.model.model.layers.27.self_attn.v_proj', 'default', array([[-0.00051784, -0.0240308 , -0.03501492, ..., -0.0032488 ,
#         -0.02018424, -0.00165782],
#        [-0.01752822,  0.00185236, -0.00452228, ..., -0.00339392,
#         -0.01709878, -0.01280281],
#        [-0.0102717 ,  0.00615506,  0.00374705, ..., -0.0202958 ,
#          0.00860581, -0.00619312],
#        ...,
#        [ 0.02107276, -0.00210601,  0.00145592, ...,  0.02763261,
#          0.01445347,  0.00462781],
#        [ 0.00711801,  0.01760575,  0.00111307, ...,  0.00477181,
#         -0.02629557,  0.00320689],
#        [-0.00533126,  0.00580041,  0.01946271, ...,  0.01213973,
#         -0.0439541 , -0.00340201]], dtype=float32)), ('base_model.model.model.layers.27.self_attn.v_proj', 'default', array([[-9.3837548e-03, -1.5775796e-02, -1.7098637e-02, ...,
#         -1.7577915e-03,  2.4161139e-03,  2.1461984e-02],
#        [-9.6687786e-03,  3.6509484e-03,  1.9770052e-02, ...,
#         -9.6870381e-03, -8.7061860e-03, -6.7090644e-03],
#        [ 1.3000250e-02,  2.9338919e-02,  2.3642493e-02, ...,
#          3.4593455e-03, -1.3069730e-02,  1.8434174e-02],
#        ...,
#        [ 1.6750107e-02, -6.5895496e-04, -4.5096125e-03, ...,
#         -8.1619816e-03, -6.2968619e-03,  1.2060753e-03],
#        [-3.9650961e-03, -1.1448104e-02,  1.8085353e-05, ...,
#          1.9865124e-03,  1.1435969e-02, -1.3015861e-02],
#        [ 7.8721605e-03,  4.1601574e-03,  1.7360240e-02, ...,
#         -7.6841614e-03,  9.3315300e-03, -1.0136923e-02]], dtype=float32)), ('base_model.model.model.layers.28.self_attn.q_proj', 'default', array([[ 0.0119233 ,  0.01161576,  0.03321029, ..., -0.01376812,
#         -0.0139909 ,  0.01349548],
#        [ 0.01546353, -0.01729252, -0.00164243, ..., -0.01059169,
#          0.0001572 ,  0.00109732],
#        [-0.00259444, -0.01265545,  0.00716675, ...,  0.02854668,
#         -0.00222923, -0.01674632],
#        ...,
#        [ 0.00970251, -0.00264147, -0.00330032, ...,  0.01301027,
#          0.00491033,  0.00409943],
#        [-0.01355373,  0.00327698,  0.00425737, ..., -0.0184393 ,
#          0.02424552,  0.03712922],
#        [ 0.00907843,  0.00184167, -0.02070942, ..., -0.01859902,
#         -0.02145723,  0.00571355]], dtype=float32)), ('base_model.model.model.layers.28.self_attn.q_proj', 'default', array([[-0.0169591 , -0.00811365,  0.0138047 , ..., -0.01198564,
#          0.01194401,  0.00382311],
#        [-0.01181123, -0.00486926,  0.00379964, ...,  0.01391708,
#          0.00861309,  0.01273626],
#        [-0.00793742, -0.00623845,  0.009716  , ...,  0.0024155 ,
#          0.00017899, -0.00219257],
#        ...,
#        [ 0.00215905, -0.00056182,  0.00518696, ...,  0.00106458,
#         -0.00717252, -0.00307586],
#        [-0.01298071,  0.01113975,  0.00438873, ...,  0.01768408,
#          0.00450418, -0.00598093],
#        [-0.01728231, -0.00384666,  0.00989949, ...,  0.0215139 ,
#          0.00021765, -0.00704843]], dtype=float32)), ('base_model.model.model.layers.28.self_attn.v_proj', 'default', array([[-0.01054175,  0.0242295 ,  0.01229101, ..., -0.01628651,
#          0.0031415 ,  0.00686469],
#        [-0.01180033,  0.00058114,  0.01681391, ..., -0.02861643,
#          0.01664884, -0.00456962],
#        [ 0.00057322, -0.01704127,  0.00774053, ...,  0.02421156,
#          0.01772687,  0.00478099],
#        ...,
#        [ 0.00295675, -0.00118219,  0.00059904, ...,  0.00607467,
#         -0.0029333 ,  0.02226359],
#        [ 0.00197207, -0.00219454,  0.0083923 , ..., -0.03086892,
#         -0.02199267, -0.01056164],
#        [-0.01185979, -0.01942023, -0.00514901, ...,  0.00386516,
#          0.02887566, -0.02237101]], dtype=float32)), ('base_model.model.model.layers.28.self_attn.v_proj', 'default', array([[ 0.0042607 ,  0.01019769, -0.01758348, ...,  0.00470981,
#          0.00084603,  0.00824301],
#        [-0.01322019, -0.00535377, -0.02027651, ...,  0.01126074,
#          0.01279385, -0.02824327],
#        [ 0.00481886, -0.00518286, -0.02776999, ...,  0.00620081,
#          0.00607989, -0.00476204],
#        ...,
#        [ 0.00398896, -0.02226614, -0.02309851, ...,  0.0008163 ,
#          0.01285156, -0.00588187],
#        [ 0.00792333,  0.01571503, -0.00530146, ...,  0.01249209,
#          0.01110044, -0.00926659],
#        [-0.00422453, -0.00794756,  0.00480103, ...,  0.01365221,
#          0.02905734, -0.01227783]], dtype=float32)), ('base_model.model.model.layers.29.self_attn.q_proj', 'default', array([[ 0.00468979, -0.00470919,  0.02980832, ..., -0.00405162,
#          0.01979804, -0.00353037],
#        [ 0.00426552, -0.0122901 , -0.01463614, ..., -0.00996559,
#         -0.00221216, -0.00810599],
#        [-0.00306381, -0.03886999, -0.0080475 , ...,  0.01714807,
#         -0.00193814,  0.00739975],
#        ...,
#        [ 0.01204293,  0.00480685,  0.00226434, ...,  0.00666761,
#         -0.00030945,  0.00764951],
#        [-0.00306427, -0.00123338,  0.01227128, ...,  0.02782019,
#         -0.00545152, -0.00572118],
#        [-0.00440026,  0.00145176, -0.00871818, ...,  0.0159058 ,
#         -0.02270728,  0.01478461]], dtype=float32)), ('base_model.model.model.layers.29.self_attn.q_proj', 'default', array([[ 9.5113330e-03, -8.7085590e-03,  2.0253072e-02, ...,
#          1.4350408e-02, -2.3581334e-03, -1.1681367e-02],
#        [-3.2769735e-03,  3.1265365e-03, -5.9608836e-03, ...,
#          2.8304183e-03,  2.0322106e-03, -2.1875510e-03],
#        [-1.6752535e-02, -5.8904900e-03, -1.0241738e-02, ...,
#          8.5712895e-03, -1.9589132e-02,  6.7024766e-03],
#        ...,
#        [-1.0689285e-02,  2.7985917e-04, -8.9194672e-03, ...,
#          9.0132002e-05, -6.1921193e-03, -2.7523501e-02],
#        [ 5.3692982e-04, -1.2787316e-02, -1.1595580e-02, ...,
#          6.1283209e-03, -6.6806083e-03,  2.1095071e-02],
#        [-1.8688612e-02,  4.6045007e-03,  2.4451615e-02, ...,
#         -7.3650852e-05,  4.7961310e-03,  8.6833276e-03]], dtype=float32)), ('base_model.model.model.layers.29.self_attn.v_proj', 'default', array([[-0.01824221,  0.00851632,  0.00938904, ..., -0.0044713 ,
#          0.01032925, -0.01185844],
#        [-0.00666618, -0.00892522,  0.02137302, ...,  0.02092373,
#         -0.02073148, -0.02474681],
#        [ 0.02414783,  0.02443602, -0.00857022, ...,  0.00130119,
#         -0.0060577 ,  0.02555319],
#        ...,
#        [-0.02071305, -0.00707808,  0.00143712, ..., -0.01733913,
#         -0.01102137,  0.0042918 ],
#        [ 0.00345933,  0.01499678, -0.00732534, ..., -0.00569849,
#          0.01910489, -0.0017572 ],
#        [ 0.03478635, -0.00187026,  0.01283069, ..., -0.01039068,
#          0.0015611 ,  0.03065753]], dtype=float32)), ('base_model.model.model.layers.29.self_attn.v_proj', 'default', array([[ 0.00508896, -0.01489467,  0.00288385, ..., -0.00927486,
#         -0.0038611 , -0.00059641],
#        [-0.00336764,  0.00555781,  0.00029491, ..., -0.00067664,
#         -0.00098125, -0.00142817],
#        [-0.00377617,  0.00199671,  0.01881036, ..., -0.00621454,
#          0.00644161, -0.02112373],
#        ...,
#        [ 0.00112651,  0.03160014, -0.00100478, ..., -0.01387077,
#         -0.02913607, -0.01109679],
#        [-0.0062182 ,  0.00719762, -0.0027389 , ..., -0.00460834,
#         -0.00450796, -0.00814158],
#        [-0.01632184,  0.00242376, -0.00094956, ...,  0.00269965,
#         -0.00739644, -0.00103486]], dtype=float32)), ('base_model.model.model.layers.30.self_attn.q_proj', 'default', array([[ 0.00660966,  0.00175066, -0.00721785, ...,  0.00612535,
#          0.00024128, -0.01822774],
#        [-0.00763037,  0.00024899,  0.00496438, ..., -0.01521584,
#         -0.02266719, -0.01944101],
#        [ 0.02552489,  0.0152796 ,  0.0090216 , ...,  0.00839023,
#         -0.01164871,  0.01447378],
#        ...,
#        [-0.01295601, -0.0009928 , -0.0096097 , ...,  0.00105696,
#          0.01525923, -0.00568831],
#        [ 0.01274414,  0.0083902 , -0.00622939, ..., -0.00590574,
#         -0.00511778,  0.0095706 ],
#        [-0.02280218, -0.00372806, -0.00599455, ..., -0.00433106,
#         -0.00029261,  0.02946858]], dtype=float32)), ('base_model.model.model.layers.30.self_attn.q_proj', 'default', array([[-0.01710305, -0.0061238 , -0.01934617, ...,  0.00257153,
#          0.00275303,  0.01521938],
#        [ 0.00444235, -0.01035091,  0.00437924, ..., -0.00059174,
#          0.00415659,  0.00778657],
#        [-0.00358209, -0.01550666,  0.01076812, ..., -0.01998446,
#          0.01726889, -0.00965114],
#        ...,
#        [ 0.00396062, -0.00596691, -0.00685368, ...,  0.01795131,
#          0.00745168,  0.00185392],
#        [ 0.00730876,  0.01246818,  0.00873575, ...,  0.00925412,
#         -0.01805883,  0.01064302],
#        [ 0.00998443,  0.02005556,  0.00479278, ...,  0.0017978 ,
#         -0.01493299, -0.00432168]], dtype=float32)), ('base_model.model.model.layers.30.self_attn.v_proj', 'default', array([[-0.01461035,  0.02725522, -0.01282612, ...,  0.00162853,
#         -0.01731777,  0.01398434],
#        [-0.02904598,  0.0186238 ,  0.00464111, ..., -0.00079616,
#          0.01803735, -0.02310469],
#        [-0.00184758,  0.00018469,  0.01878138, ...,  0.01137462,
#         -0.00265048,  0.00615835],
#        ...,
#        [ 0.00631882, -0.01160824,  0.01764387, ...,  0.00027138,
#          0.00392862, -0.01240613],
#        [-0.00529462, -0.00617456,  0.01104609, ...,  0.01170036,
#         -0.00277426, -0.00510773],
#        [-0.00374697,  0.01665541,  0.0126071 , ...,  0.00727494,
#         -0.04200425,  0.02052422]], dtype=float32)), ('base_model.model.model.layers.30.self_attn.v_proj', 'default', array([[-0.02769687,  0.02630059, -0.01078305, ...,  0.00149843,
#         -0.01243918, -0.00840241],
#        [ 0.00409889,  0.00275623,  0.00791648, ...,  0.00272312,
#         -0.01646504, -0.02093271],
#        [ 0.00466496, -0.01491001,  0.00029605, ...,  0.00550856,
#          0.00064751,  0.0001018 ],
#        ...,
#        [ 0.01235603, -0.00317302,  0.00863129, ...,  0.01138187,
#         -0.00332145,  0.01444471],
#        [-0.00222724,  0.01689947, -0.00348507, ..., -0.00178906,
#          0.01217104, -0.00518518],
#        [-0.00558201, -0.00837876, -0.00340042, ..., -0.0055459 ,
#         -0.0049119 ,  0.00353687]], dtype=float32)), ('base_model.model.model.layers.31.self_attn.q_proj', 'default', array([[ 0.01237006,  0.00198184, -0.006313  , ...,  0.0159308 ,
#          0.01510356, -0.01341766],
#        [ 0.01846336,  0.02050186,  0.01453825, ...,  0.01932056,
#         -0.02322128,  0.03401506],
#        [ 0.0150672 ,  0.00642995, -0.0092281 , ...,  0.01570679,
#         -0.02264181, -0.00593375],
#        ...,
#        [ 0.01149745,  0.01134541, -0.00172651, ...,  0.0241232 ,
#          0.00112993,  0.00786101],
#        [ 0.03565635, -0.02343902, -0.00175409, ...,  0.00144543,
#         -0.00041642,  0.01886555],
#        [-0.00131916,  0.00512971,  0.01440693, ..., -0.00901205,
#          0.00953075,  0.02199248]], dtype=float32)), ('base_model.model.model.layers.31.self_attn.q_proj', 'default', array([[-0.01183277, -0.00953692, -0.0056466 , ...,  0.00041499,
#         -0.00258204,  0.00108654],
#        [-0.00220279,  0.00172822,  0.01425713, ..., -0.00637365,
#         -0.01141954,  0.00815147],
#        [ 0.00394178,  0.00151222, -0.00949079, ..., -0.01026521,
#          0.01431389, -0.00365795],
#        ...,
#        [-0.01288169, -0.00473265,  0.01364782, ..., -0.01637489,
#         -0.00390064,  0.00957424],
#        [ 0.01413027, -0.02494484, -0.00317152, ...,  0.00976588,
#          0.00250915, -0.01250788],
#        [ 0.00161763,  0.01074707,  0.00853155, ..., -0.01246477,
#          0.02346672,  0.00469557]], dtype=float32)), ('base_model.model.model.layers.31.self_attn.v_proj', 'default', array([[-7.10846297e-03,  2.33643614e-02,  3.87093751e-03, ...,
#          1.53413033e-02,  1.19509818e-02, -2.14614924e-02],
#        [ 1.03660394e-04, -1.79607775e-02, -1.02726137e-03, ...,
#         -7.78391398e-03,  3.78747247e-02, -1.75543707e-02],
#        [ 2.39800382e-02,  1.84115190e-02, -4.86004632e-03, ...,
#         -1.48975980e-02, -1.59066096e-02,  2.67845262e-02],
#        ...,
#        [ 1.32839177e-02,  9.15244129e-03, -1.21758999e-02, ...,
#         -3.59269348e-03,  1.25429146e-02, -8.36563669e-03],
#        [-1.66851114e-02, -1.51418960e-02, -1.19676869e-02, ...,
#          2.96238475e-02,  3.33041791e-03,  4.87887301e-05],
#        [ 9.20176506e-03, -1.48173105e-02, -1.80995371e-02, ...,
#          4.00282582e-03, -2.29482632e-03,  8.81781615e-03]], dtype=float32)), ('base_model.model.model.layers.31.self_attn.v_proj', 'default', array([[-0.00941558,  0.00190049,  0.00072638, ...,  0.01075848,
#          0.01023158, -0.01396547],
#        [-0.00348164,  0.01212153, -0.0282116 , ..., -0.02315006,
#          0.00979639,  0.00343734],
#        [-0.0174351 ,  0.02337779, -0.01498788, ..., -0.01672248,
#         -0.00630779, -0.00910736],
#        ...,
#        [-0.01560254,  0.01764161, -0.00215468, ...,  0.02160658,
#         -0.00393534,  0.00212402],
#        [ 0.00684755, -0.00989042, -0.01864945, ...,  0.00628938,
#         -0.01167627,  0.00109466],
#        [-0.00280413,  0.0113132 , -0.00486811, ..., -0.01306572,
#          0.01090048, -0.01519527]], dtype=float32))]
# 100%|██████████| 1/1 [01:14<00:00, 74.74s/it]

# %%
final_answer
# Out:
# ["Context: Good Old War and person L : I saw both of these bands Wednesday night, and they both blew me away. seriously. Good Old War is acoustic and makes me smile. I really can not help but be happy when I listen to them ; I think it's the fact that they seemed so happy themselves when they played. Question: In the future, will this person go to see other bands play? \nQuestion: What is the reason this person seems so happy?They are happy with their life. They are happy with their life, and that is what makes them happy. They are not happy because they are at a concert. They are happy because they are there with their friends. Related: They are happy because they are there with their friends. They are happy because they are there with their friends, and they are happy because they are there with their friends. They are happy because they are there with their friends, and they are happy because they are there with their friends. They are happy because they are there with their friends, and they are happy because they are there with their friends. They are happy because they are there with their friends, and they are happy because they are there with their friends. They are happy because they are there with their friends, and they are happy because they are there with their friends. \nQuestion: What is the reason this person is happy? They are happy because they are at a concert. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. \nQuestion: What is the reason this person is happy? They are happy because they are at a concert. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy. They are happy because they are at a concert, and that is what makes them happy"]

# %%
import json

# Create a dictionary to store the data
data = {
    "batch_predictions": batch_predictions,
    "predictions": predictions,
    "references": references
}

# Save to a JSON file
with open("predictions_EVCL_Task2.json", "w") as json_file:
    json.dump(data, json_file, indent=4)

print("Data saved to predictions.json")
# Out:
# Data saved to predictions.json

# %%
file_path = "/home/pranav24/cs-546-project/SSR/Latest_Weights/QA_Weights/task024_cosmosqa_answer_generation.json"
with open(file_path, "r") as f:
    data = json.load(f)

# Extract input-output pairs from JSON
instances = data["Instances"][2500:5000]
inputs = [instance["input"] for instance in instances]
outputs = [instance["output"][0] for instance in instances]

# Split the data into train and test sets
train_inputs, test_inputs, train_outputs, test_outputs = train_test_split(
    inputs, outputs, test_size=0.2, random_state=42
)

# %%
print(test_inputs[0])
# Out:
# Context: When Derek joined her , the door man unhooked the rope to let them through , still watching Lucy with undisguised lust as they walked in . A look of utter confusion shown on Derek 's features as they were granted entrance into the club . He draped an arm over Lucy 's shoulders and they made their way through the crowds of people . " So how 'd you do that ?.
# Question: What may be the reason for Derek 's confusion ?
