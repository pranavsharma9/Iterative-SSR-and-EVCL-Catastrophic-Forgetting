# %% [markdown]
# ### QS+SA SSR Only (QA Evaluation)

# %%
import json
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel
from datasets import Dataset
from torch.utils.data import DataLoader
import torch
import pyro
import pyro.distributions as dist
from tqdm import tqdm
import os

# Load the JSON file
file_path = "/home/panshul2/cs-546/Iterative-SSR-and-EVCL-Catastrophic-Forgetting/SSR/Latest_Weights/QA_Weights/task024_cosmosqa_answer_generation.json"
with open(file_path, "r") as f:
    data = json.load(f)

# Extract input-output pairs from JSON
instances = data["Instances"][2500:5000]
inputs = [instance["input"] for instance in instances]
outputs = [instance["output"][0] for instance in instances]

# Split the data into train and test sets
train_inputs, test_inputs, train_outputs, test_outputs = train_test_split(
    inputs, outputs, test_size=0.2, random_state=42
)

# Convert data to Hugging Face Dataset format
train_ds = Dataset.from_dict({"input": train_inputs, "output": train_outputs})
test_ds = Dataset.from_dict({"input": test_inputs, "output": test_outputs})

# Tokenizer setup
base_model_path = "meta-llama/Meta-Llama-3-8B"  # Replace with actual model path
tokenizer = AutoTokenizer.from_pretrained(base_model_path)

# Check if tokenizer has a padding token, if not, set the eos_token as padding token
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Tokenization function
def tokenize_function(examples):
    model_inputs = tokenizer(
        examples["input"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )
    labels = tokenizer(
        examples["output"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )["input_ids"]
    model_inputs["labels"] = labels
    return model_inputs

# Tokenize datasets
tokenized_train_ds = train_ds.map(tokenize_function, batched=True, remove_columns=["input", "output"])
tokenized_test_ds = test_ds.map(tokenize_function, batched=True, remove_columns=["input", "output"])

# Convert datasets to PyTorch format
tokenized_train_ds.set_format("torch")
tokenized_test_ds.set_format("torch")

# Create DataLoaders
batch_size = 16  # Adjust as needed
train_loader = DataLoader(tokenized_train_ds, batch_size=batch_size, shuffle=True)
eval_loader = DataLoader(tokenized_test_ds, batch_size=batch_size)

# Define the model and load weights
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_enable_fp32_cpu_offload=True,
)
fine_tuned_weights_path = "/home/panshul2/cs-546/Iterative-SSR-and-EVCL-Catastrophic-Forgetting/SSR/Only_SSR_Weights/QA_SA_SSR-fine-tuned-llama-lora"

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    quantization_config=bnb_config,
    device_map="auto"
)
model = PeftModel.from_pretrained(base_model, fine_tuned_weights_path)
DEVICE = model.device

# Generate predictions
predictions = []
references = []

output_file_path = "/home/panshul2/cs-546/Iterative-SSR-and-EVCL-Catastrophic-Forgetting/SSR/Only_SSR_Weights/Evaluation_data/predictions_SSR_QA_SA_Final_Task_QA.json"

if os.path.exists(output_file_path):
    with open(output_file_path, "r") as f:
        saved_data = json.load(f)
else:
    saved_data = {"predictions": [], "references": []}

print("Generating predictions incrementally:")

print("Generating predictions:")

for i in tqdm(range(0, len(test_inputs), batch_size)):  # Loop in batches
    batch_inputs = test_inputs[i:i + batch_size]
    batch_references = test_outputs[i:i + batch_size]

    # Tokenize the inputs in a batch
    inputs_tokenized = tokenizer(batch_inputs, padding=True, truncation=True, return_tensors="pt").to(DEVICE)

    with torch.no_grad():

        # Generate predictions using the tokenized inputs
        generated_ids = model.generate(
                input_ids=inputs_tokenized["input_ids"],
                attention_mask=inputs_tokenized["attention_mask"],
                max_new_tokens=30,  
                min_length=10,  
                no_repeat_ngram_size=2,  
                num_return_sequences=1,
                top_p=0.9,  
                temperature=0.7  
            )
        
    batch_predictions = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    predictions.extend(batch_predictions)
    references.extend(batch_references)

    saved_data["predictions"].extend(batch_predictions)
    saved_data["references"].extend(batch_references)

    # Save incrementally to JSON
    with open(output_file_path, "w") as json_file:
        json.dump(saved_data, json_file, indent=4)
# Out:
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating predictions incrementally:
# Generating predictions:
#   0%|          | 0/32 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 1/32 [00:06<03:16,  6.33s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 2/32 [00:12<03:08,  6.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   9%|▉         | 3/32 [00:18<03:00,  6.22s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  12%|█▎        | 4/32 [00:24<02:52,  6.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  16%|█▌        | 5/32 [00:30<02:46,  6.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  19%|█▉        | 6/32 [00:37<02:39,  6.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  22%|██▏       | 7/32 [00:43<02:34,  6.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  25%|██▌       | 8/32 [00:49<02:26,  6.11s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  28%|██▊       | 9/32 [00:55<02:20,  6.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  31%|███▏      | 10/32 [01:01<02:15,  6.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  34%|███▍      | 11/32 [01:07<02:10,  6.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  38%|███▊      | 12/32 [01:13<02:02,  6.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  41%|████      | 13/32 [01:19<01:55,  6.07s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  44%|████▍     | 14/32 [01:25<01:49,  6.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  47%|████▋     | 15/32 [01:32<01:44,  6.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  50%|█████     | 16/32 [01:38<01:38,  6.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  53%|█████▎    | 17/32 [01:44<01:31,  6.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  56%|█████▋    | 18/32 [01:50<01:25,  6.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  59%|█████▉    | 19/32 [01:56<01:19,  6.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  62%|██████▎   | 20/32 [02:02<01:12,  6.03s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  66%|██████▌   | 21/32 [02:08<01:06,  6.04s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  69%|██████▉   | 22/32 [02:14<01:01,  6.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  72%|███████▏  | 23/32 [02:21<00:55,  6.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  75%|███████▌  | 24/32 [02:27<00:50,  6.26s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  78%|███████▊  | 25/32 [02:33<00:43,  6.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  81%|████████▏ | 26/32 [02:39<00:37,  6.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  84%|████████▍ | 27/32 [02:45<00:30,  6.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  88%|████████▊ | 28/32 [02:51<00:24,  6.12s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  91%|█████████ | 29/32 [02:58<00:18,  6.16s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  94%|█████████▍| 30/32 [03:04<00:12,  6.23s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 31/32 [03:10<00:06,  6.20s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|██████████| 32/32 [03:16<00:00,  6.13s/it]

# %%
import evaluate
rouge = evaluate.load("rouge")
results = rouge.compute(predictions=predictions, references=references)

# Display the results
print("\nROUGE Scores:")
print(results)
# Out:
# ROUGE Scores:
# {'rouge1': np.float64(0.07532156779368768), 'rouge2': np.float64(0.017035762044340534), 'rougeL': np.float64(0.05820545362960167), 'rougeLsum': np.float64(0.06459406343944764)}

# %% [markdown]
# ### SA

# %%
import json
from sklearn.model_selection import train_test_split
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig
from peft import PeftModel
from datasets import Dataset
from torch.utils.data import DataLoader
import torch
import pyro
import pyro.distributions as dist
from tqdm import tqdm
import os




file_path = "/home/panshul2/cs-546/Iterative-SSR-and-EVCL-Catastrophic-Forgetting/SSR/Latest_Weights/QA_QG_SA_Weights/task1312_amazonreview_polarity_classification.json"

with open(file_path, "r") as f:
    data = json.load(f)

# # Extract input-output pairs from JSON
instruction="""\nInstruction: Craft one correct answer to the question given in input. Be straight to the point and do not give incorrect answers. Only output the answer without restating the question or context. Be consistent with the context and use common sense."""
final_instruction="Now, ensure to only give the answer and not restate the question or context. \nAnswer:"
# Extract input-output pairs from JSON
instances = data["Instances"][4500:5000]
test_inputs = [instruction+instance["input"]+final_instruction for instance in instances]
test_outputs = [instance["output"][0] for instance in instances]

# Split the data into train and test sets


# Convert data to Hugging Face Dataset format
test_ds = Dataset.from_dict({"input": test_inputs, "output": test_outputs})

# Tokenizer setup
base_model_path = "meta-llama/Meta-Llama-3-8B"  # Replace with actual model path
tokenizer = AutoTokenizer.from_pretrained(base_model_path)

# Check if tokenizer has a padding token, if not, set the eos_token as padding token
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

# Tokenization function
def tokenize_function(examples):
    model_inputs = tokenizer(
        examples["input"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )
    labels = tokenizer(
        examples["output"],
        truncation=True,
        padding="max_length",
        max_length=512,
    )["input_ids"]
    model_inputs["labels"] = labels
    return model_inputs

# Tokenize datasets
tokenized_test_ds = test_ds.map(tokenize_function, batched=True, remove_columns=["input", "output"])

# Convert datasets to PyTorch format
tokenized_test_ds.set_format("torch")


# Define the model and load weights
bnb_config = BitsAndBytesConfig(
    load_in_8bit=True,
    llm_int8_enable_fp32_cpu_offload=True,
)
fine_tuned_weights_path = "/home/panshul2/cs-546/Iterative-SSR-and-EVCL-Catastrophic-Forgetting/SSR/Only_SSR_Weights/QA_SA_SSR-fine-tuned-llama-lora"

base_model = AutoModelForCausalLM.from_pretrained(
    base_model_path,
    quantization_config=bnb_config,
    device_map="auto"
)
model = PeftModel.from_pretrained(base_model, fine_tuned_weights_path)
DEVICE = model.device

# Generate predictions
predictions = []
references = []

output_file_path = "/home/panshul2/cs-546/Iterative-SSR-and-EVCL-Catastrophic-Forgetting/SSR/Only_SSR_Weights/Evaluation_data/predictions_SSR_QA_SA_Final_Task_SA.json"

if os.path.exists(output_file_path):
    with open(output_file_path, "r") as f:
        saved_data = json.load(f)
else:
    saved_data = {"predictions": [], "references": []}

print("Generating predictions incrementally:")

print("Generating predictions:")
batch_size=16
for i in tqdm(range(0, len(test_inputs), batch_size)):  # Loop in batches
    batch_inputs = test_inputs[i:i + batch_size]
    batch_references = test_outputs[i:i + batch_size]

    # Tokenize the inputs in a batch
    inputs_tokenized = tokenizer(batch_inputs, padding=True, truncation=True, return_tensors="pt").to(DEVICE)

    with torch.no_grad():

        # Generate predictions using the tokenized inputs
        generated_ids = model.generate(
                input_ids=inputs_tokenized["input_ids"],
                attention_mask=inputs_tokenized["attention_mask"],
                max_new_tokens=30,  
                min_length=10,  
                no_repeat_ngram_size=2,  
                num_return_sequences=1,
                top_p=0.9,  
                temperature=0.7  
            )
        
    batch_predictions = tokenizer.batch_decode(generated_ids, skip_special_tokens=True)
    predictions.extend(batch_predictions)
    references.extend(batch_references)

    saved_data["predictions"].extend(batch_predictions)
    saved_data["references"].extend(batch_references)

    # Save incrementally to JSON
    with open(output_file_path, "w") as json_file:
        json.dump(saved_data, json_file, indent=4)
# Out:
# Map:   0%|          | 0/500 [00:00<?, ? examples/s]
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# Generating predictions incrementally:
# Generating predictions:
#   0%|          | 0/32 [00:00<?, ?it/s]Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   3%|▎         | 1/32 [00:07<03:54,  7.56s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   6%|▋         | 2/32 [00:13<03:26,  6.89s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#   9%|▉         | 3/32 [00:19<03:06,  6.44s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  12%|█▎        | 4/32 [00:25<02:54,  6.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  16%|█▌        | 5/32 [00:32<02:49,  6.28s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  19%|█▉        | 6/32 [00:38<02:41,  6.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  22%|██▏       | 7/32 [00:44<02:35,  6.24s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  25%|██▌       | 8/32 [00:50<02:28,  6.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  28%|██▊       | 9/32 [00:56<02:21,  6.14s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  31%|███▏      | 10/32 [01:02<02:14,  6.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  34%|███▍      | 11/32 [01:08<02:06,  6.02s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  38%|███▊      | 12/32 [01:14<02:00,  6.00s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  41%|████      | 13/32 [01:20<01:53,  5.99s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  44%|████▍     | 14/32 [01:26<01:47,  5.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  47%|████▋     | 15/32 [01:32<01:41,  5.97s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  50%|█████     | 16/32 [01:38<01:35,  5.95s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  53%|█████▎    | 17/32 [01:44<01:29,  5.94s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  56%|█████▋    | 18/32 [01:50<01:23,  5.98s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  59%|█████▉    | 19/32 [01:56<01:20,  6.19s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  62%|██████▎   | 20/32 [02:02<01:13,  6.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  66%|██████▌   | 21/32 [02:08<01:06,  6.08s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  69%|██████▉   | 22/32 [02:14<01:00,  6.05s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  72%|███████▏  | 23/32 [02:21<00:55,  6.17s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  75%|███████▌  | 24/32 [02:27<00:48,  6.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  78%|███████▊  | 25/32 [02:33<00:42,  6.09s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  81%|████████▏ | 26/32 [02:39<00:37,  6.21s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  84%|████████▍ | 27/32 [02:45<00:30,  6.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  88%|████████▊ | 28/32 [02:51<00:24,  6.13s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  91%|█████████ | 29/32 [02:57<00:18,  6.10s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  94%|█████████▍| 30/32 [03:04<00:12,  6.18s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
#  97%|█████████▋| 31/32 [03:10<00:06,  6.15s/it]Setting `pad_token_id` to `eos_token_id`:None for open-end generation.
# A decoder-only architecture is being used, but right-padding was detected! For correct generation results, please set `padding_side='left'` when initializing the tokenizer.
# 100%|██████████| 32/32 [03:15<00:00,  6.12s/it]
